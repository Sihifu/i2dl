# %% [markdown]
# # Autoencoder for MNIST
#
# Welcome to this notebook where you'll be training an autoencoder using the MNIST dataset, which comprises handwritten digits. This exercise is the last where we present you with a structured skeleton to work with. However, in following exercises, we will only provide you with the dataset, task, and a test scenario, enabling you to test your skills and compete with your peers on our leaderboards. Get ready to dive in and showcase your deep learning expertise!
#
#
# ## Your task:
#
# Autoencoders have various applications, including unsupervised pretraining using unlabeled data, followed by fine-tuning the encoder with labeled data. This approach can greatly enhance performance when there is only a little amount of labeled data but a lot of unlabeled data available.
#
# In this exercise, you will use the MNIST dataset, consisting of 60,000 images of handwritten digits. However, not all the image labels are available to you. Your first objective is to train an autoencoder to accurately reproduce these unlabeled images.
#
# Afterwards, you will transfer the weights of the pretrained encoder and perform fine-tuning on a classifier using the available labeled data. This technique is commonly known as **transfer learning**, which allows you to leverage the knowledge gained from the autoencoder to improve the classification of the handwritten digits.

# %%
# For automatic file reloading as usual
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# Uncomment the following cell to mount your gdrive if you are using the notebook in google colab:

# %%
# Use the following lines if you want to use Google Colab
# We presume you created a folder "i2dl" within your main drive folder, and put the exercise there.
# NOTE: terminate all other colab sessions that use GPU!
# NOTE 2: Make sure the correct exercise folder (e.g exercise_08) is given.

# from google.colab import drive
# import os

"""
from google.colab import drive
import os
gdrive_path='/content/gdrive/MyDrive/i2dl/exercise_08'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
"""
# Out:
# "\nfrom google.colab import drive\nimport os\ngdrive_path='/content/gdrive/MyDrive/i2dl/exercise_08'\n\n# This will mount your google drive under 'MyDrive'\ndrive.mount('/content/gdrive', force_remount=True)\n# In order to access the files in this notebook we have to navigate to the correct folder\nos.chdir(gdrive_path)\n# Check manually if all files are present\n"

# %% [markdown]
# ### Set up PyTorch environment in colab
# - Enable GPU via Runtime --> Change runtime type --> GPU

# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os, sys
import shutil
import torch
import torch.nn as nn
from torchvision import transforms
from exercise_code.image_folder_dataset import ImageFolderDataset
from torch.utils.tensorboard import SummaryWriter
from time import sleep
from tqdm import tqdm
from exercise_code.tests.base_tests import bcolors

torch.manual_seed(42)

os.environ['KMP_DUPLICATE_LIB_OK']='True' # To prevent the kernel from dying.

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note: Google Colab</h3>
#     <p>
# In case you don't have a GPU, you can run this notebook on Google Colab where you can access a GPU for free, but, of course, you can also run this notebook on your CPU.
#          </p>
# </div>

# %%
device = torch.device("mps" if torch.backends.mps.is_available else "cpu")
print('You are using the following device: ', device)
# Out:
# You are using the following device:  mps

# %% [markdown]
# ## Setup TensorBoard
#
# In the previous exercise (Exercise 07), you learned how to use TensorBoard effectively. Let's use it again to enhance the convenience of debugging your network and the training process. Throughout this notebook, feel free to implement additional logs or visualizations into your TensorBoard, further improving your analysis and understanding of the network's behavior.

# %%
################# COLAB ONLY #################
# %load_ext tensorboard
# %tensorboard --logdir=./ --port 6006

# Use the cmd for less trouble, if you can. From the working directory, run: tensorboard --logdir=./ --port 6006

# %% [markdown]
# # 1. The MNIST Dataset
#
# First, let's download the MNIST dataset. As mentioned at the beginning of this notebook, MNIST is a dataset of 60,000 images depicting handwritten digits. However, labeling such a large dataset can be a costly process, leaving us in a challenging situation.
#
# To overcome this, a practical approach is to label a small subset of the images. Let's consider a scenario where you have hired another student to perform the labeling task for you. After some time, you have been provided with 300 labeled images. Out of these, 100 images will be used for training, another 100 for validation, and the remaining 100 for testing. Undoubtedly, this poses a challenge due to the limited number of labeled samples.
#
# Now, you have the flexibility to define any transforms that you deem necessary, either at this point or at a later stage. However, it's important to note that during the final evaluation on the server, no transformations will be applied to the test set.
#
# Feel free to experiment with various transforms as you proceed (you can also pass without any transforms).
#
#
# **Note**: We do **not** apply any transformations or normalization to the test set at the time of final evaluation on our server.

# %%
transform = transforms.Compose([])

########################################################################
# TODO: Feel free to define transforms (Only data augmentation)        #
########################################################################


transform = transforms.Compose([transforms.Normalize((0.5,),(0.5,))])

########################################################################
#                           END OF YOUR CODE                           #
########################################################################

i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
mnist_root = os.path.join(i2dl_exercises_path, "datasets", "mnist")

train_100_dataset = ImageFolderDataset(root=mnist_root,images='train_images.pt',labels='train_labels.pt',force_download=False,verbose=True,transform=transform)
val_100_dataset = ImageFolderDataset(root=mnist_root,images='val_images.pt',labels='val_labels.pt',force_download=False,verbose=True,transform=transform)
test_100_dataset = ImageFolderDataset(root=mnist_root,images='test_images.pt',labels='test_labels.pt',force_download=False,verbose=True,transform=transform)

# We also set up the unlabeled images which we will use later
unlabeled_train = ImageFolderDataset(root=mnist_root,images='unlabeled_train_images.pt',force_download=False,verbose=True,transform=transform)
unlabeled_val = ImageFolderDataset(root=mnist_root,images='unlabeled_val_images.pt',force_download=False,verbose=True,transform=transform)
# Out:
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip

# %% [markdown]
# The dataset consists of tuples of 28x28 pixel PIL images and a label that is an integer from 0 to 9.
#
# Let's turn a few of the images into numpy arrays, to look at their shape and visualize them and see if the labels we paid for are correct.

# %%
plt.rcParams['figure.figsize'] = (16,16) # Make the figures a bit bigger

indices_arr = [83, 98, 92, 99, 78, 97, 90, 95, 93, 96]
for i, index in enumerate(indices_arr):
    image = np.array(train_100_dataset[index][0].squeeze()) # get the image of the data sample
    label = train_100_dataset[index][1] # get the label of the data sample
    plt.subplot(1, 10, i + 1)
    plt.imshow(image, cmap='gray', interpolation='none')
    plt.title("Class {}".format(label))
    
plt.tight_layout()
print('The shape of our greyscale images: ', image.shape)
# Out:
# The shape of our greyscale images:  (28, 28)

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note: Starting Simple</h3>
#     <p>
# Regardless of the size of the dataset, the first step is to evaluate the performance of a simple classifier. It is advisable to always start with a straightforward approach when tackling a problem and gradually build upon it to determine which changes yield improvements.</p>
# </div>
#
# # 2. A Simple Classifier
#
# In `exercise_code/models.py`, we prepared all classes for you, which you will finalize throughout the notebook to build an Autoencoder and an image classifier with PyTorch.
#
# <!-- In case image does not show, uncomment the following:
#  ![network_split](img/network_split.png)
#  -->
# <img name="network_split" src="https://i2dl.vc.in.tum.de/static/images/exercise_08/network_split.png">
#
#
# ## 2.1 The Encoder
#
# Unlike previous models, we are going to split up the model into two parts: the `encoder` and the `classifier`. The `classifier` has a fixed task, generating predictions given a one-dimensional input. On the other hand, the `encoder`'s task is to extract meaningful information from the input, enabling the classifier to make accurate decisions.
#
# For now, both networks will be similar in design and consist of linear layers coupled with auxiliary layers. This split-up will be relevant later, e.g., by using convolutional layers, which are introduced in the lecture. We are going to set up the `encoder` now.
#
# Think about a good network architecture. You have complete freedom in this regard and can devise any network structure you think might be fitting. (\*)
#
# Have a look at the documentation of `torch.nn` at https://pytorch.org/docs/stable/nn.html to learn how to use this module in order to build your network!
#
# Then implement your architecture: initialize it in `__init__()` and assign it to `self.model`. This is particularly easy using `nn.Sequential()`, where you only have to pass the list of your layers.
#
# To make your model customizable and support parameter search, do not use hardcoded hyperparameters - instead, pass them as a simple dictionary `hparams` (here, `n_hidden` is the number of neurons in the hidden layer) when initializing `models`.
#
# Here is a simple example:
#
# ```python
#         self.model = nn.Sequential(
#             nn.Linear(input_size, self.hparams["n_hidden"]),
#             nn.ReLU(),
#             nn.Linear(self.hparams["n_hidden"], num_classes)
#         )
# ```
#
# Have a look at the forward path in `forward(self, x)`, which is so easy that you don't need to implement it yourself.
#
# As PyTorch automatically computes the gradients, that's all you need to do! There is no need to manually calculate derivatives for the backward paths anymore! :)
#
#
# ____
# \* *The size of your final model must be less than 20 MB, which is approximately equivalent to 5 Mio. params. Note that this limit is quite lenient, you will probably need much fewer parameters!*
#
# *In order to keep things simple, you should only use fully connected layers for this task, as we need to revert the encoder architecture later on in the notebook.*
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>Encoder</code> class initialization in <code>exercise_code/models.py</code>.
#     </p>
# </div>

# %% [markdown]
# ## 2.2 The Classifier
#
# Now let's implement the classifier. The classifier will utilize the encoder that you have defined in the above cell. By looking at `Classifier.forward`, you can see that we are essentially concatenating the `classifier`and the `encoder` together. Therefore, it is crucial to ensure that the input shape of the classifier matches the output shape of the encoder you implemented above
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>1. Implement the <code>Classifier</code> class network initialization in <code>exercise_code/models.py</code>.
#     </p>
#     <p>2. Define in the next cell your hyperparameters in a dictionary called 'hparams'.
#     </p>
# </div>

# %%
hparams = {}
########################################################################
# TODO: Define your hyper parameters here!                             #
########################################################################

hparams = {
    "input_size": 28*28,
    "batch_size": 25,
    "num_layers": 3,
    "lr": 3e-4,
    "reg": 4e-5,
    "n_hidden": 2**7,
    "num_classes": 10,
    "num_workers": 10,
    "latent_dim": 20,
    "device": "mps",
    "batch_norm": True,
    "layer_norm": False,
    "shortcut": True,
    "epochs": 25,
    "optimizer": "ADAM",
    "loss_func": torch.nn.CrossEntropyLoss()
}

########################################################################
#                           END OF YOUR CODE                           #
########################################################################

# %% [markdown]
# ## 2.3 Optimizer
# Lastly, implement the function `set_optimizer` to define your optimizer. Here the documentation of `torch.optim` at https://pytorch.org/docs/stable/optim.html might be helpful.
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>set_optimizer</code> method of the <code>Classifier</code> in <code>exercise_code/models.py</code>.
#     </p>
# </div>

# %% [markdown]
# ## 2.4 Training & Validation Step
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p> Let's take a closer look at the training pipeline outlined below. It is explicitly written here in its entirety to provide you with a comprehensive understanding of its structure. Additionally, you can refer back to this pipeline whenever you encounter any uncertainties or need guidance.
#  </p>
# </div>

# %%
 # One of the most crucial things in deep learning is to understand the training pipeline:
 # 1. Forward()          --> The forward pass of the network, to calculate the currnent loss.
 # 2. Backward()         --> The backward pass of the network, to calculate the gradients w.r.t the loss, calculated in the previous stage.
 # 3. Optimizer_step()   --> Update the weights w.r.t their corresponding gradients and the learnign rate.

def create_tqdm_bar(iterable, desc):
    return tqdm(enumerate(iterable),total=len(iterable), ncols=150, desc=desc)


def train_classifier(classifier, train_loader, val_loader, loss_func, tb_logger, epochs=10, name="default"):
    """
    Train the classifier for a number of epochs.
    """
    optimizer = classifier.optimizer
    classifier = classifier.to(device)
    validation_loss = 0
    for epoch in range(epochs):
        
        training_loss = 0
        
        # Training stage, where we want to update the parameters.
        classifier.train()  # Set the model to training mode
        
        # Create a progress bar for the training loop.
        training_loop = create_tqdm_bar(train_loader, desc=f'Training Epoch [{epoch + 1}/{epochs}]')
        for train_iteration, batch in training_loop:
            optimizer.zero_grad() # Reset the gradients - VERY important! Otherwise they accumulate.
            images, labels = batch # Get the images and labels from the batch, in the fashion we defined in the dataset and dataloader.
            images, labels = images.to(device), labels.to(device) # Send the data to the device (GPU or CPU) - it has to be the same device as the model.

            # Flatten the images to a vector. This is done because the classifier expects a vector as input.
            # Could also be done by reshaping the images in the dataset.
            images = images.view(images.shape[0], -1) 

            pred = classifier(images) # Stage 1: Forward().
            loss = loss_func(pred, labels, classifier) # Compute the loss over the predictions and the ground truth.
            loss.backward()  # Stage 2: Backward().
            optimizer.step() # Stage 3: Update the parameters.

            training_loss += loss_func.compute_loss_without_regularization(pred, labels).item()

            # Update the progress bar.
            training_loop.set_postfix(curr_train_loss = "{:.8f}".format(training_loss / (train_iteration + 1)), val_loss = "{:.8f}".format(validation_loss))

            # Update the tensorboard logger.
            tb_logger.add_scalar(f'classifier_{name}/train_loss', loss_func.compute_loss_without_regularization(pred, labels).item(), 
                                epoch * len(train_loader) + train_iteration)

        # Validation stage, where we don't want to update the parameters. Pay attention to the classifier.eval() line
        # and "with torch.no_grad()" wrapper.
        classifier.eval()
        val_loop = create_tqdm_bar(val_loader, desc=f'Validation Epoch [{epoch + 1}/{epochs}]')
        validation_loss = 0
        with torch.no_grad():
            for val_iteration, batch in val_loop:
                images, labels = batch
                images, labels = images.to(device), labels.to(device)

                images = images.view(images.shape[0], -1) 
                pred = classifier(images)
                loss = loss_func(pred, labels, classifier)
                validation_loss += loss_func.compute_loss_without_regularization(pred, labels).item()

                # Update the progress bar.
                val_loop.set_postfix(val_loss = "{:.8f}".format(validation_loss / (val_iteration + 1)))

                # Update the tensorboard logger.
                tb_logger.add_scalar(f'classifier_{name}/val_loss', loss_func.compute_loss_without_regularization(pred, labels).item(), 
                                     epoch * len(val_loader) + val_iteration)
        
        # This value is used for the progress bar of the training loop.
        validation_loss /= len(val_loader)

# %% [markdown]
# ## 2.5 Fit Classification Model with Trainer
# Now it's finally time to train your model.
# Run the following cell to see the behold the magic of deep learning at play.

# %%
from exercise_code.models import Classifier
from exercise_code.models import Encoder
from exercise_code.loss import Loss

# Create the encoder and the classifier.
encoder = Encoder(hparams).to(device)
classifier = Classifier(hparams, encoder).to(device)

# Create a tensorboard logger.
# NOTE: In order to see the logs, run the following command in the terminal: tensorboard --logdir=./
# Also, in order to reset the logs, delete the logs folder MANUALLY.

path = os.path.join('logs', 'cls_logs')
num_of_runs = len(os.listdir(path)) if os.path.exists(path) else 0
path = os.path.join(path, f'run_{num_of_runs + 1}')

tb_logger = SummaryWriter(path)

# Train the classifier.
labled_train_loader = torch.utils.data.DataLoader(train_100_dataset, batch_size=hparams['batch_size'], shuffle=True)
labled_val_loader = torch.utils.data.DataLoader(val_100_dataset, batch_size=hparams['batch_size'], shuffle=False)

epochs = hparams.get('epochs', 10)
loss_func = Loss(**hparams).to(device) # The loss function we use for classification.
train_classifier(classifier, labled_train_loader, labled_val_loader, loss_func, tb_logger, epochs=epochs, name="Default")

print("Finished training!")
print("How did we do? Let's check the accuracy of the defaut classifier on the training and validation sets:")
print(f"Training Acc: {classifier.getAcc(labled_train_loader)[1] * 100}%")
print(f"Validation Acc: {classifier.getAcc(labled_val_loader)[1] * 100}%")
# Out:
# Training Epoch [1/25]: 100%|███████████████████████████████████████████| 4/4 [00:07<00:00,  1.82s/it, curr_train_loss=2.11099845, val_loss=0.00000000]
# Validation Epoch [1/25]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 33.87it/s, val_loss=2.16811693]
# Training Epoch [2/25]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00, 18.34it/s, curr_train_loss=1.48167574, val_loss=2.16811693]
# Validation Epoch [2/25]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,
100%|██████████████████████████████████████████| 4/4 [00:00<00:00, 20.87it/s, curr_train_loss=0.12856578, val_loss=1.19534342]
# Validation Epoch [20/25]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.84it/s, val_loss=1.19426359]
# Training Epoch [21/25]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00, 19.09it/s, curr_train_loss=0.10477422, val_loss=1.19426359]
# Validation Epoch [21/25]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 74.35it/s, val_loss=1.19558766]
# Training Epoch [22/25]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00, 19.66it/s, curr_train_loss=0.11785646, val_loss=1.19558766]
# Validation Epoch [22/25]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 72.29it/s, val_loss=1.18487437]
# Training Epoch [23/25]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00, 18.77it/s, curr_train_loss=0.10488206, val_loss=1.18487437]
# Validation Epoch [23/25]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 75.49it/s, val_loss=1.18936706]
# Training Epoch [24/25]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00, 19.75it/s, curr_train_loss=0.11823633, val_loss=1.18936706]
# Validation Epoch [24/25]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 66.93it/s, val_loss=1.21280408]
# Training Epoch [25/25]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00, 18.37it/s, curr_train_loss=0.09244114, val_loss=1.21280408]
# Validation Epoch [25/25]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 64.22it/s, val_loss=1.22587459]
# Finished training!
# How did we do? Let's check the accuracy of the defaut classifier on the training and validation sets:
# Training Acc: 100.0%
# Validation Acc: 66.0%

# %% [markdown]
# ## 2.6 Hyperparameter tuning

# %%
hparams = {
    "input_size": 28*28,
    "batch_size": 25,
    "num_layers": 3,
    "lr": 3e-4,
    "reg": 4e-5,
    "n_hidden": 2**7,
    "num_classes": 10,
    "num_workers": 10,
    "latent_dim": 20,
    "device": "mps",
    "batch_norm": False,
    "layer_norm": True,
    "shortcut": True,
    "epochs": 50,
    "optimizer": "ADAM",
    "loss_function": torch.nn.CrossEntropyLoss(),
    "patience": 10,
    "patience_delta": 0.02
}

num_searches=40

class MyClassifier(Classifier):
    def __init__(self,hparams,encoder=Encoder(hparams).to(device)):
        super().__init__(hparams,encoder=encoder)
        self.num_operation=0

# %%
from exercise_code.hyperparameter_tuning import random_search

# datasets are very small 100 samples each
labled_train_loader=torch.utils.data.DataLoader(train_100_dataset, batch_size=hparams['batch_size'], shuffle=True)
labled_val_loader = torch.utils.data.DataLoader(val_100_dataset, batch_size=hparams['batch_size'], shuffle=False)

new_config={
        "num_layers": ([0,4,8,12], 'item'),
        "reg": ([1e-3, 1e-6], "log"),
        "lr": ([1e-3,1e-6], "log"),
        "n_hidden": ([2**6,2**7,2**8], "item")
    }

for key,value in hparams.items():
    if key not in (new_config):
        new_config[key]=([value],"item")


best_model, best_config, results  = random_search(
    train_100_dataset, val_100_dataset,
    random_search_spaces = new_config,
    model=MyClassifier,
    num_search = 40)
# Out:
# Evaluating Config #1 [of 40]:
#  {'num_layers': 0, 'reg': 0.0001260719341667588, 'lr': 0.0008699115452605381, 'n_hidden': 256, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.435322; val loss: 2.434774
# (Epoch 2 / 50) train loss: 2.078090; val loss: 2.264619
# (Epoch 3 / 50) train loss: 1.820279; val loss: 1.996512
# (Epoch 4 / 50) train loss: 1.411887; val loss: 1.703552
# (Epoch 5 / 50) train loss: 1.091163; val loss: 1.601605
# (Epoch 6 / 50) train loss: 0.854308; val loss: 1.379056
# (Epoch 7 / 50) train loss: 0.676480; val loss: 1.324119
# (Epoch 8 / 50) train loss: 0.519413; val loss: 1.169863
# (Epoch 9 / 50) train loss: 0.388089; val loss: 1.153567
# (Epoch 10 / 50) train loss: 0.332328; val loss: 1.090159
# (Epoch 11 / 50) train loss: 0.301024; val loss: 0.999111
# (Epoch 12 / 50) train loss: 0.222823; val loss: 1.147586
# (Epoch 13 / 50) train loss: 0.141460; val loss: 1.144980
# (Epoch 14 / 50) train loss: 0.120297; val loss: 0.967027
# (Epoch 15 / 50) train loss: 0.091186; val loss: 1.037352
# (Epoch 16 / 50) train loss: 0.076039; val loss: 1.145796
# (Epoch 17 / 50) train loss: 0.067149; val loss: 1.164842
# (Epoch 18 / 50) train loss: 0.051733; val loss: 1.154474
# (Epoch 19 / 50) train loss: 0.042003; val loss: 1.106445
# (Epoch 20 / 50) train loss: 0.036798; val loss: 1.105728
# (Epoch 21 / 50) train loss: 0.031240; val loss: 1.132692
# (Epoch 22 / 50) train loss: 0.028404; val loss: 1.113496
# (Epoch 23 / 50) train loss: 0.025131; val loss: 1.104269
# (Epoch 24 / 50) train loss: 0.023085; val loss: 1.111234
# Stopping early at epoch 23!
# Best val loss of current config:1.1112337708473206
#
# Evaluating Config #2 [of 40]:
#  {'num_layers': 0, 'reg': 8.300014852875459e-05, 'lr': 1.737597754233451e-05, 'n_hidden': 256, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.449731; val loss: 2.466287
# (Epoch 2 / 50) train loss: 2.368145; val loss: 2.411600
# (Epoch 3 / 50) train loss: 2.297716; val loss: 2.373093
# (Epoch 4 / 50) train loss: 2.240472; val loss: 2.350963
# (Epoch 5 / 50) train loss: 2.188208; val loss: 2.336884
# (Epoch 6 / 50) train loss: 2.143622; val loss: 2.330117
# (Epoch 7 / 50) train loss: 2.101399; val loss: 2.321149
# (Epoch 8 / 50) train loss: 2.065578; val loss: 2.310348
# (Epoch 9 / 50) train loss: 2.033028; val loss: 2.298048
# (Epoch 10 / 50) train loss: 1.998531; val loss: 2.281636
# (Epoch 11 / 50) train loss: 1.965246; val loss: 2.263352
# (Epoch 12 / 50) train loss: 1.934898; val loss: 2.241409
# (Epoch 13 / 50) train loss: 1.903250; val loss: 2.217129
# (Epoch 14 / 50) train loss: 1.874041; val loss: 2.192958
# (Epoch 15 / 50) train loss: 1.842349; val loss: 2.171866
# (Epoch 16 / 50) train loss: 1.812196; val loss: 2.149620
# (Epoch 17 / 50) train loss: 1.783680; val loss: 2.127302
# (Epoch 18 / 50) train loss: 1.754729; val loss: 2.105257
# (Epoch 19 / 50) train loss: 1.727658; val loss: 2.083831
# (Epoch 20 / 50) train loss: 1.700265; val loss: 2.062996
# (Epoch 21 / 50) train loss: 1.672764; val loss: 2.043768
# (Epoch 22 / 50) train loss: 1.646360; val loss: 2.026240
# (Epoch 23 / 50) train loss: 1.621011; val loss: 2.008709
# (Epoch 24 / 50) train loss: 1.594998; val loss: 1.992408
# (Epoch 25 / 50) train loss: 1.569634; val loss: 1.974679
# (Epoch 26 / 50) train loss: 1.544157; val loss: 1.958596
# (Epoch 27 / 50) train loss: 1.521032; val loss: 1.942013
# (Epoch 28 / 50) train loss: 1.496680; val loss: 1.927228
# (Epoch 29 / 50) train loss: 1.473718; val loss: 1.911358
# (Epoch 30 / 50) train loss: 1.449801; val loss: 1.895747
# (Epoch 31 / 50) train loss: 1.427385; val loss: 1.880154
# (Epoch 32 / 50) train loss: 1.404838; val loss: 1.866589
# (Epoch 33 / 50) train loss: 1.383292; val loss: 1.852071
# (Epoch 34 / 50) train loss: 1.361389; val loss: 1.839548
# (Epoch 35 / 50) train loss: 1.340189; val loss: 1.827898
# (Epoch 36 / 50) train loss: 1.319604; val loss: 1.817843
# (Epoch 37 / 50) train loss: 1.298175; val loss: 1.803921
# (Epoch 38 / 50) train loss: 1.277908; val loss: 1.791887
# (Epoch 39 / 50) train loss: 1.258573; val loss: 1.779012
# (Epoch 40 / 50) train loss: 1.238810; val loss: 1.767288
# (Epoch 41 / 50) train loss: 1.219188; val loss: 1.756851
# (Epoch 42 / 50) train loss: 1.200530; val loss: 1.748226
# (Epoch 43 / 50) train loss: 1.182340; val loss: 1.739930
# (Epoch 44 / 50) train loss: 1.163690; val loss: 1.726654
# (Epoch 45 / 50) train loss: 1.145590; val loss: 1.715266
# (Epoch 46 / 50) train loss: 1.127491; val loss: 1.707099
# (Epoch 47 / 50) train loss: 1.110314; val loss: 1.698683
# (Epoch 48 / 50) train loss: 1.092937; val loss: 1.689997
# (Epoch 49 / 50) train loss: 1.076035; val loss: 1.681791
# (Epoch 50 / 50) train loss: 1.059862; val loss: 1.674120
# Best val loss of current config:1.6741203665733337
#
# Evaluating Config #3 [of 40]:
#  {'num_layers': 0, 'reg': 7.489281633264417e-06, 'lr': 1.4441981074692478e-05, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.543603; val loss: 2.497967
# (Epoch 2 / 50) train loss: 2.482608; val loss: 2.455991
# (Epoch 3 / 50) train loss: 2.427371; val loss: 2.414656
# (Epoch 4 / 50) train loss: 2.374665; val loss: 2.375632
# (Epoch 5 / 50) train loss: 2.325462; val loss: 2.338161
#  {'num_layers': 4, 'reg': 1.5338547650716708e-06, 'lr': 5.708603955280023e-06, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.565890; val loss: 2.930165
# (Epoch 2 / 50) train loss: 2.538399; val loss: 2.911691
# (Epoch 3 / 50) train loss: 2.512820; val loss: 2.891157
# (Epoch 4 / 50) train loss: 2.485230; val loss: 2.870974
# (Epoch 5 / 50) train loss: 2.458530; val loss: 2.849998
# (Epoch 6 / 50) train loss: 2.430915; val loss: 2.829049
# (Epoch 7 / 50) train loss: 2.402364; val loss: 2.808804
# (Epoch 8 / 50) train loss: 2.374704; val loss: 2.787474
# (Epoch 9 / 50) train loss: 2.344040; val loss: 2.767339
# (Epoch 10 / 50) train loss: 2.316567; val loss: 2.746607
# (Epoch 11 / 50) train loss: 2.290058; val loss: 2.725938
# (Epoch 12 / 50) train loss: 2.263053; val loss: 2.705408
# (Epoch 13 / 50) train loss: 2.234139; val loss: 2.685862
# (Epoch 14 / 50) train loss: 2.204569; val loss: 2.667330
# (Epoch 15 / 50) train loss: 2.177552; val loss: 2.648866
# (Epoch 16 / 50) train loss: 2.153370; val loss: 2.630447
# (Epoch 17 / 50) train loss: 2.126191; val loss: 2.612782
# (Epoch 18 / 50) train loss: 2.101730; val loss: 2.595924
# (Epoch 19 / 50) train loss: 2.079056; val loss: 2.579657
# (Epoch 20 / 50) train loss: 2.056612; val loss: 2.563531
# (Epoch 21 / 50) train loss: 2.035266; val loss: 2.548748
# (Epoch 22 / 50) train loss: 2.013428; val loss: 2.534017
# (Epoch 23 / 50) train loss: 1.994070; val loss: 2.519697
# (Epoch 24 / 50) train loss: 1.974346; val loss: 2.505912
# (Epoch 25 / 50) train loss: 1.956625; val loss: 2.492043
# (Epoch 26 / 50) train loss: 1.938355; val loss: 2.479027
# (Epoch 27 / 50) train loss: 1.921030; val loss: 2.465310
# (Epoch 28 / 50) train loss: 1.904569; val loss: 2.452595
# (Epoch 29 / 50) train loss: 1.888355; val loss: 2.439490
# (Epoch 30 / 50) train loss: 1.873230; val loss: 2.427702
# (Epoch 31 / 50) train loss: 1.857745; val loss: 2.415299
# (Epoch 32 / 50) train loss: 1.842714; val loss: 2.403601
# (Epoch 33 / 50) train loss: 1.828285; val loss: 2.392067
# (Epoch 34 / 50) train loss: 1.813899; val loss: 2.380690
# (Epoch 35 / 50) train loss: 1.799749; val loss: 2.369698
# (Epoch 36 / 50) train loss: 1.786221; val loss: 2.358918
# (Epoch 37 / 50) train loss: 1.772949; val loss: 2.347963
# (Epoch 38 / 50) train loss: 1.759331; val loss: 2.337717
# (Epoch 39 / 50) train loss: 1.747219; val loss: 2.327157
# (Epoch 40 / 50) train loss: 1.734031; val loss: 2.317418
# (Epoch 41 / 50) train loss: 1.721217; val loss: 2.307504
# (Epoch 42 / 50) train loss: 1.708829; val loss: 2.298456
# (Epoch 43 / 50) train loss: 1.696887; val loss: 2.288872
# (Epoch 44 / 50) train loss: 1.685062; val loss: 2.279048
# (Epoch 45 / 50) train loss: 1.673001; val loss: 2.270053
# (Epoch 46 / 50) train loss: 1.661329; val loss: 2.261073
# (Epoch 47 / 50) train loss: 1.649676; val loss: 2.252420
# (Epoch 48 / 50) train loss: 1.638681; val loss: 2.243611
# (Epoch 49 / 50) train loss: 1.627835; val loss: 2.234318
# (Epoch 50 / 50) train loss: 1.616739; val loss: 2.225248
# Best val loss of current config:2.2252475023269653
#
# Evaluating Config #5 [of 40]:
#  {'num_layers': 12, 'reg': 7.491721378354521e-06, 'lr': 0.00013043424171291985, 'n_hidden': 256, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.134962; val loss: 2.158178
# (Epoch 2 / 50) train loss: 1.735456; val loss: 1.914144
# (Epoch 3 / 50) train loss: 1.426757; val loss: 1.748892
# (Epoch 4 / 50) train loss: 1.204635; val loss: 1.631175
# (Epoch 5 / 50) train loss: 1.026933; val loss: 1.505993
# (Epoch 6 / 50) train loss: 0.876563; val loss: 1.407075
# (Epoch 7 / 50) train loss: 0.752428; val loss: 1.340555
# (Epoch 8 / 50) train loss: 0.660948; val loss: 1.287300
# (Epoch 9 / 50) train loss: 0.582765; val loss: 1.252140
# (Epoch 10 / 50) train loss: 0.519358; val loss: 1.222220
# (Epoch 11 / 50) train loss: 0.468409; val loss: 1.204373
# (Epoch 12 / 50) train loss: 0.421835; val loss: 1.180887
# (Epoch 13 / 50) train loss: 0.384663; val loss: 1.161003
# (Epoch 14 / 50) train loss: 0.352456; val loss: 1.146512
# (Epoch 15 / 50) train loss: 0.324218; val loss: 1.142744
# (Epoch 16 / 50) train loss: 0.300472; val loss: 1.140286
# (Epoch 17 / 50) train loss: 0.279550; val loss: 1.132401
# (Epoch 18 / 50) train loss: 0.260321; val loss: 1.123707
# (Epoch 19 / 50) train loss: 0.244208; val loss: 1.117098
# (Epoch 20 / 50) train loss: 0.229429; val loss: 1.112400
# (Epoch 21 / 50) train loss: 0.216485; val loss: 1.107513
# (Epoch 22 / 50) train loss: 0.204189; val loss: 1.108472
# (Epoch 23 / 50) train loss: 0.193753; val loss: 1.110617
# (Epoch 24 / 50) train loss: 0.183948; val loss: 1.106044
# (Epoch 25 / 50) train loss: 0.174658; val loss: 1.096801
# (Epoch 26 / 50) train loss: 0.166685; val loss: 1.091650
# (Epoch 27 / 50) train loss: 0.159386; val loss: 1.091378
# (Epoch 28 / 50) train loss: 0.152560; val loss: 1.089931
# (Epoch 29 / 50) train loss: 0.146222; val loss: 1.099577
# (Epoch 30 / 50) train loss: 0.139853; val loss: 1.096903
# (Epoch 31 / 50) train loss: 0.134712; val loss: 1.090695
# (Epoch 32 / 50) train loss: 0.129162; val loss: 1.086157
# (Epoch 33 / 50) train loss: 0.124214; val loss: 1.089856
# (Epoch 34 / 50) train loss: 0.119848; val loss: 1.086897
# (Epoch 35 / 50) train loss: 0.115473; val loss: 1.086654
# (Epoch 36 / 50) train loss: 0.111234; val loss: 1.091801
# (Epoch 37 / 50) train loss: 0.107573; val loss: 1.090322
# (Epoch 38 / 50) train loss: 0.104040; val loss: 1.085436
# (Epoch 39 / 50) train loss: 0.100585; val loss: 1.086898
# (Epoch 40 / 50) train loss: 0.097317; val loss: 1.089588
# (Epoch 41 / 50) train loss: 0.094214; val loss: 1.088348
# (Epoch 42 / 50) train loss: 0.091254; val loss: 1.085592
# (Epoch 43 / 50) train loss: 0.088570; val loss: 1.088667
# (Epoch 44 / 50) train loss: 0.086074; val loss: 1.091716
# (Epoch 45 / 50) train loss: 0.083570; val loss: 1.089601
# (Epoch 46 / 50) train loss: 0.081103; val loss: 1.088328
# (Epoch 47 / 50) train loss: 0.078977; val loss: 1.086889
# (Epoch 48 / 50) train loss: 0.076786; val loss: 1.090095
# (Epoch 49 / 50) train loss: 0.074702; val loss: 1.091521
# (Epoch 50 / 50) train loss: 0.072764; val loss: 1.089152
# Best val loss of current config:1.0891516208648682
#
# Evaluating Config #6 [of 40]:
#  {'num_layers': 4, 'reg': 2.320848924470395e-06, 'lr': 0.0004118673557283451, 'n_hidden': 64, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.697207; val loss: 2.076258
# (Epoch 2 / 50) train loss: 1.491966; val loss: 1.722948
# (Epoch 3 / 50) train loss: 1.046081; val loss: 1.666374
# (Epoch 4 / 50) train loss: 0.791292; val loss: 1.650107
# (Epoch 5 / 50) train loss: 0.619450; val loss: 1.543419
# (Epoch 6 / 50) train loss: 0.481487; val loss: 1.480796
# (Epoch 7 / 50) train loss: 0.397742; val loss: 1.410422
# (Epoch 8 / 50) train loss: 0.323843; val loss: 1.374164
# (Epoch 9 / 50) train loss: 0.262760; val loss: 1.346985
# (Epoch 10 / 50) train loss: 0.218120; val loss: 1.348688
# (Epoch 11 / 50) train loss: 0.182370; val loss: 1.350812
# (Epoch 12 / 50) train loss: 0.152825; val loss: 1.311218
# (Epoch 13 / 50) train loss: 0.134447; val loss: 1.304969
# (Epoch 14 / 50) train loss: 0.116329; val loss: 1.320514
# (Epoch 15 / 50) train loss: 0.101256; val loss: 1.311414
# (Epoch 16 / 50) train loss: 0.089945; val loss: 1.316000
# (Epoch 17 / 50) train loss: 0.080811; val loss: 1.303583
# (Epoch 18 / 50) train loss: 0.073141; val loss: 1.311646
# (Epoch 19 / 50) train loss: 0.066777; val loss: 1.336146
# (Epoch 20 / 50) train loss: 0.061262; val loss: 1.354913
# (Epoch 21 / 50) train loss: 0.056649; val loss: 1.347062
# (Epoch 22 / 50) train loss: 0.052656; val loss: 1.351058
# (Epoch 23 / 50) train loss: 0.048996; val loss: 1.371499
# (Epoch 24 / 50) train loss: 0.045983; val loss: 1.377757
# (Epoch 25 / 50) train loss: 0.043314; val loss: 1.378846
# (Epoch 26 / 50) train loss: 0.040737; val loss: 1.392095
# (Epoch 27 / 50) train loss: 0.038403; val loss: 1.408681
# (Epoch 28 / 50) train loss: 0.036463; val loss: 1.420926
# Stopping early at epoch 27!
# Best val loss of current config:1.4209260046482086
#
# Evaluating Config #7 [of 40]:
#  {'num_layers': 4, 'reg': 8.709207471165196e-05, 'lr': 6.561639121721984e-06, 'n_hidden': 256, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.577001; val loss: 2.785908
# (Epoch 2 / 50) train loss: 2.537478; val loss: 2.756028
# (Epoch 3 / 50) train loss: 2.501891; val loss: 2.727889
# (Epoch 4 / 50) train loss: 2.466195; val loss: 2.701258
# (Epoch 5 / 50) train loss: 2.433766; val loss: 2.676657
# (Epoch 6 / 50) train loss: 2.398037; val loss: 2.653836
# (Epoch 7 / 50) train loss: 2.367540; val loss: 2.631444
# (Epoch 8 / 50) train loss: 2.335434; val loss: 2.610427
# (Epoch 9 / 50) train loss: 2.303814; val loss: 2.590227
# (Epoch 10 / 50) train loss: 2.274835; val loss: 2.570196
# (Epoch 11 / 50) train loss: 2.244799; val loss: 2.551601
# (Epoch 12 / 50) train loss: 2.215656; val loss: 2.533749
# (Epoch 13 / 50) train loss: 2.188302; val loss: 2.516265
# (Epoch 14 / 50) train loss: 2.162325; val loss: 2.498289
# (Epoch 15 / 50) train loss: 2.135363; val loss: 2.481580
# (Epoch 16 / 50) train loss: 2.110899; val loss: 2.465934
# (Epoch 17 / 50) train loss: 2.085585; val loss: 2.448796
# (Epoch 18 / 50) train loss: 2.061741; val loss: 2.431768
# (Epoch 19 / 50) train loss: 2.037950; val loss: 2.415350
# (Epoch 20 / 50) train loss: 2.015386; val loss: 2.400047
# (Epoch 21 / 50) train loss: 1.994087; val loss: 2.384215
# (Epoch 22 / 50) train loss: 1.972279; val loss: 2.369249
# (Epoch 23 / 50) train loss: 1.951521; val loss: 2.354579
# (Epoch 24 / 50) train loss: 1.930628; val loss: 2.340134
# (Epoch 25 / 50) train loss: 1.910833; val loss: 2.326460
# (Epoch 26 / 50) train loss: 1.892380; val loss: 2.312470
# (Epoch 27 / 50) train loss: 1.873737; val loss: 2.298716
# (Epoch 28 / 50) train loss: 1.854704; val loss: 2.285999
# (Epoch 29 / 50) train loss: 1.838084; val loss: 2.272674
# (Epoch 30 / 50) train loss: 1.820019; val loss: 2.260237
# (Epoch 31 / 50) train loss: 1.802664; val loss: 2.249089
# (Epoch 32 / 50) train loss: 1.786413; val loss: 2.237519
# (Epoch 33 / 50) train loss: 1.770129; val loss: 2.226356
# (Epoch 34 / 50) train loss: 1.754383; val loss: 2.214962
# (Epoch 35 / 50) train loss: 1.739118; val loss: 2.204031
# (Epoch 36 / 50) train loss: 1.723790; val loss: 2.193182
# (Epoch 37 / 50) train loss: 1.708656; val loss: 2.183690
# (Epoch 38 / 50) train loss: 1.694451; val loss: 2.173236
# (Epoch 39 / 50) train loss: 1.679521; val loss: 2.163106
# (Epoch 40 / 50) train loss: 1.665214; val loss: 2.153531
# (Epoch 41 / 50) train loss: 1.651386; val loss: 2.144114
# (Epoch 42 / 50) train loss: 1.637068; val loss: 2.134852
# (Epoch 43 / 50) train loss: 1.623616; val loss: 2.125459
# (Epoch 44 / 50) train loss: 1.610419; val loss: 2.116058
# (Epoch 45 / 50) train loss: 1.597230; val loss: 2.107243
# (Epoch 46 / 50) train loss: 1.583943; val loss: 2.098202
# (Epoch 47 / 50) train loss: 1.570789; val loss: 2.090019
# (Epoch 48 / 50) train loss: 1.557729; val loss: 2.081270
# (Epoch 49 / 50) train loss: 1.545093; val loss: 2.072622
# (Epoch 50 / 50) train loss: 1.532885; val loss: 2.064038
# Best val loss of current config:2.064038336277008
#
# Evaluating Config #8 [of 40]:
#  {'num_layers': 4, 'reg': 5.365594814939285e-06, 'lr': 3.144481168828228e-05, 'n_hidden': 256, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.830660; val loss: 2.877001
# (Epoch 2 / 50) train loss: 2.586789; val loss: 2.757048
# (Epoch 3 / 50) train loss: 2.401324; val loss: 2.651082
# (Epoch 4 / 50) train loss: 2.243491; val loss: 2.559552
# (Epoch 5 / 50) train loss: 2.119552; val loss: 2.485027
# (Epoch 6 / 50) train loss: 2.023230; val loss: 2.421017
# (Epoch 7 / 50) train loss: 1.934467; val loss: 2.366637
# (Epoch 8 / 50) train loss: 1.859373; val loss: 2.316975
# (Epoch 9 / 50) train loss: 1.790690; val loss: 2.271023
# (Epoch 10 / 50) train loss: 1.731768; val loss: 2.232238
# (Epoch 11 / 50) train loss: 1.675070; val loss: 2.195275
# (Epoch 12 / 50) train loss: 1.626604; val loss: 2.160058
# (Epoch 13 / 50) train loss: 1.576320; val loss: 2.126311
# (Epoch 14 / 50) train loss: 1.529237; val loss: 2.096193
# (Epoch 15 / 50) train loss: 1.484510; val loss: 2.068573
# (Epoch 16 / 50) train loss: 1.442374; val loss: 2.042286
# (Epoch 17 / 50) train loss: 1.401872; val loss: 2.016676
# (Epoch 18 / 50) train loss: 1.360052; val loss: 1.991413
# (Epoch 19 / 50) train loss: 1.322460; val loss: 1.967464
# (Epoch 20 / 50) train loss: 1.283595; val loss: 1.942234
# (Epoch 21 / 50) train loss: 1.243238; val loss: 1.918138
# (Epoch 22 / 50) train loss: 1.205888; val loss: 1.894894
# (Epoch 23 / 50) train loss: 1.167194; val loss: 1.875886
# (Epoch 24 / 50) train loss: 1.131436; val loss: 1.858404
# (Epoch 25 / 50) train loss: 1.094131; val loss: 1.839475
# (Epoch 26 / 50) train loss: 1.057360; val loss: 1.819304
# (Epoch 27 / 50) train loss: 1.021425; val loss: 1.801039
# (Epoch 28 / 50) train loss: 0.986219; val loss: 1.783054
# (Epoch 29 / 50) train loss: 0.952680; val loss: 1.763573
# (Epoch 30 / 50) train loss: 0.918338; val loss: 1.748975
# (Epoch 31 / 50) train loss: 0.885399; val loss: 1.736726
# (Epoch 32 / 50) train loss: 0.853865; val loss: 1.723002
# (Epoch 33 / 50) train loss: 0.826157; val loss: 1.710747
# (Epoch 34 / 50) train loss: 0.793309; val loss: 1.690897
# (Epoch 35 / 50) train loss: 0.765831; val loss: 1.673691
# (Epoch 36 / 50) train loss: 0.736794; val loss: 1.661975
# (Epoch 37 / 50) train loss: 0.711024; val loss: 1.649769
# (Epoch 38 / 50) train loss: 0.684826; val loss: 1.638393
# (Epoch 39 / 50) train loss: 0.659690; val loss: 1.624720
# (Epoch 40 / 50) train loss: 0.636213; val loss: 1.611807
# (Epoch 41 / 50) train loss: 0.614184; val loss: 1.604564
# (Epoch 42 / 50) train loss: 0.591360; val loss: 1.597021
# (Epoch 43 / 50) train loss: 0.570736; val loss: 1.589303
# (Epoch 44 / 50) train loss: 0.550363; val loss: 1.580851
# (Epoch 45 / 50) train loss: 0.530658; val loss: 1.573968
# (Epoch 46 / 50) train loss: 0.512402; val loss: 1.565974
# (Epoch 47 / 50) train loss: 0.493824; val loss: 1.558491
# (Epoch 48 / 50) train loss: 0.478055; val loss: 1.553059
# (Epoch 49 / 50) train loss: 0.460664; val loss: 1.545227
# (Epoch 50 / 50) train loss: 0.445849; val loss: 1.538033
# Best val loss of current config:1.5380333065986633
#
# Evaluating Config #9 [of 40]:
#  {'num_layers': 8, 'reg': 0.0007288158018170961, 'lr': 1.1002817757119952e-05, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 3.510645; val loss: 3.170920
# (Epoch 2 / 50) train loss: 3.412011; val loss: 3.131185
# (Epoch 3 / 50) train loss: 3.335961; val loss: 3.096333
# (Epoch 4 / 50) train loss: 3.262198; val loss: 3.064603
# (Epoch 5 / 50) train loss: 3.206094; val loss: 3.037129
#  {'num_layers': 8, 'reg': 0.00016461114809578322, 'lr': 0.0001988983664081667, 'n_hidden': 64, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.974699; val loss: 2.506416
# (Epoch 2 / 50) train loss: 2.329598; val loss: 2.178376
# (Epoch 3 / 50) train loss: 1.881705; val loss: 1.900613
# (Epoch 4 / 50) train loss: 1.549495; val loss: 1.771987
# (Epoch 5 / 50) train loss: 1.259115; val loss: 1.715852
# (Epoch 6 / 50) train loss: 1.043355; val loss: 1.624491
# (Epoch 7 / 50) train loss: 0.873729; val loss: 1.511131
# (Epoch 8 / 50) train loss: 0.729882; val loss: 1.483688
# (Epoch 9 / 50) train loss: 0.607972; val loss: 1.416069
# (Epoch 10 / 50) train loss: 0.524068; val loss: 1.355206
# (Epoch 11 / 50) train loss: 0.444082; val loss: 1.344642
# (Epoch 12 / 50) train loss: 0.381615; val loss: 1.302786
# (Epoch 13 / 50) train loss: 0.325323; val loss: 1.306814
# (Epoch 14 / 50) train loss: 0.276743; val loss: 1.313401
# (Epoch 15 / 50) train loss: 0.237251; val loss: 1.284161
# (Epoch 16 / 50) train loss: 0.207299; val loss: 1.287153
# (Epoch 17 / 50) train loss: 0.178509; val loss: 1.296110
# (Epoch 18 / 50) train loss: 0.158599; val loss: 1.269944
# (Epoch 19 / 50) train loss: 0.141351; val loss: 1.263328
# (Epoch 20 / 50) train loss: 0.126220; val loss: 1.278402
# (Epoch 21 / 50) train loss: 0.114776; val loss: 1.272391
# (Epoch 22 / 50) train loss: 0.105666; val loss: 1.265896
# (Epoch 23 / 50) train loss: 0.097529; val loss: 1.278142
# (Epoch 24 / 50) train loss: 0.090678; val loss: 1.280753
# (Epoch 25 / 50) train loss: 0.084821; val loss: 1.282382
# (Epoch 26 / 50) train loss: 0.080027; val loss: 1.281607
# (Epoch 27 / 50) train loss: 0.075715; val loss: 1.281914
# (Epoch 28 / 50) train loss: 0.071827; val loss: 1.290720
# (Epoch 29 / 50) train loss: 0.068230; val loss: 1.281302
# (Epoch 30 / 50) train loss: 0.065189; val loss: 1.284840
# (Epoch 31 / 50) train loss: 0.062297; val loss: 1.290260
# (Epoch 32 / 50) train loss: 0.059756; val loss: 1.295224
# (Epoch 33 / 50) train loss: 0.057342; val loss: 1.289665
# (Epoch 34 / 50) train loss: 0.055164; val loss: 1.291892
# (Epoch 35 / 50) train loss: 0.053147; val loss: 1.297071
# (Epoch 36 / 50) train loss: 0.051374; val loss: 1.297689
# (Epoch 37 / 50) train loss: 0.049664; val loss: 1.298231
# (Epoch 38 / 50) train loss: 0.048001; val loss: 1.301470
# (Epoch 39 / 50) train loss: 0.046523; val loss: 1.299770
# Stopping early at epoch 38!
# Best val loss of current config:1.2997697740793228
#
# Evaluating Config #11 [of 40]:
# (Epoch 41 / 50) train loss: 0.329382; val loss: 1.372996
# (Epoch 42 / 50) train loss: 0.318607; val loss: 1.369283
# (Epoch 43 / 50) train loss: 0.308239; val loss: 1.362093
# (Epoch 44 / 50) train loss: 0.298507; val loss: 1.355190
# (Epoch 45 / 50) train loss: 0.288961; val loss: 1.353793
# (Epoch 46 / 50) train loss: 0.280318; val loss: 1.351451
# (Epoch 47 / 50) train loss: 0.271761; val loss: 1.346476
# (Epoch 48 / 50) train loss: 0.263794; val loss: 1.343641
# (Epoch 49 / 50) train loss: 0.255935; val loss: 1.341643
# (Epoch 50 / 50) train loss: 0.248693; val loss: 1.340165
# Best val loss of current config:1.3401651978492737
#
# Evaluating Config #12 [of 40]:
#  {'num_layers': 4, 'reg': 1.883961226309519e-05, 'lr': 2.8149125897613947e-06, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.845291; val loss: 2.986344
# (Epoch 2 / 50) train loss: 2.819608; val loss: 2.966959
# (Epoch 3 / 50) train loss: 2.798110; val loss: 2.947893
# (Epoch 4 / 50) train loss: 2.775351; val loss: 2.929636
# (Epoch 5 / 50) train loss: 2.754433; val loss: 2.911683
# (Epoch 6 / 50) train loss: 2.734165; val loss: 2.893427
# (Epoch 7 / 50) train loss: 2.714482; val loss: 2.876297
# (Epoch 8 / 50) train loss: 2.694167; val loss: 2.859586
# (Epoch 9 / 50) train loss: 2.674458; val loss: 2.843078
# (Epoch 10 / 50) train loss: 2.656140; val loss: 2.826672
# (Epoch 11 / 50) train loss: 2.637753; val loss: 2.811338
# (Epoch 12 / 50) train loss: 2.619936; val loss: 2.796259
# (Epoch 13 / 50) train loss: 2.601607; val loss: 2.782039
# (Epoch 14 / 50) train loss: 2.584137; val loss: 2.768051
# (Epoch 15 / 50) train loss: 2.567328; val loss: 2.754718
# (Epoch 16 / 50) train loss: 2.549529; val loss: 2.741776
# (Epoch 17 / 50) train loss: 2.532972; val loss: 2.728421
# (Epoch 18 / 50) train loss: 2.516115; val loss: 2.715999
# (Epoch 19 / 50) train loss: 2.499633; val loss: 2.704412
# (Epoch 20 / 50) train loss: 2.483794; val loss: 2.693155
# (Epoch 21 / 50) train loss: 2.467838; val loss: 2.681288
# (Epoch 22 / 50) train loss: 2.451855; val loss: 2.669939
# (Epoch 23 / 50) train loss: 2.435712; val loss: 2.659384
# (Epoch 24 / 50) train loss: 2.420210; val loss: 2.648240
# (Epoch 25 / 50) train loss: 2.404461; val loss: 2.637312
# (Epoch 26 / 50) train loss: 2.388897; val loss: 2.627258
# (Epoch 27 / 50) train loss: 2.374238; val loss: 2.617525
# (Epoch 28 / 50) train loss: 2.359012; val loss: 2.607187
# (Epoch 29 / 50) train loss: 2.343762; val loss: 2.597564
# (Epoch 30 / 50) train loss: 2.328644; val loss: 2.588206
# (Epoch 31 / 50) train loss: 2.314134; val loss: 2.578106
# (Epoch 32 / 50) train loss: 2.299328; val loss: 2.568872
# (Epoch 33 / 50) train loss: 2.284642; val loss: 2.559240
# (Epoch 34 / 50) train loss: 2.270323; val loss: 2.549813
# (Epoch 35 / 50) train loss: 2.256321; val loss: 2.540525
# (Epoch 36 / 50) train loss: 2.241634; val loss: 2.532028
# (Epoch 37 / 50) train loss: 2.227966; val loss: 2.523062
# (Epoch 38 / 50) train loss: 2.214057; val loss: 2.514837
# (Epoch 39 / 50) train loss: 2.199756; val loss: 2.506057
# (Epoch 40 / 50) train loss: 2.185968; val loss: 2.497594
# (Epoch 41 / 50) train loss: 2.172565; val loss: 2.489125
# (Epoch 42 / 50) train loss: 2.159428; val loss: 2.480967
# (Epoch 43 / 50) train loss: 2.145961; val loss: 2.472642
# (Epoch 44 / 50) train loss: 2.132415; val loss: 2.464155
# (Epoch 45 / 50) train loss: 2.119152; val loss: 2.455667
# (Epoch 46 / 50) train loss: 2.106697; val loss: 2.448150
# (Epoch 47 / 50) train loss: 2.093207; val loss: 2.440790
# (Epoch 48 / 50) train loss: 2.080154; val loss: 2.432957
# (Epoch 49 / 50) train loss: 2.067604; val loss: 2.425548
# (Epoch 50 / 50) train loss: 2.055242; val loss: 2.418503
# Best val loss of current config:2.4185031056404114
#
# Evaluating Config #13 [of 40]:
#  {'num_layers': 0, 'reg': 3.6498259848962837e-06, 'lr': 6.824093879106967e-05, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.023290; val loss: 2.295712
# (Epoch 2 / 50) train loss: 1.690734; val loss: 2.168590
# (Epoch 3 / 50) train loss: 1.481432; val loss: 2.081738
# (Epoch 4 / 50) train loss: 1.313766; val loss: 1.988240
# (Epoch 5 / 50) train loss: 1.173644; val loss: 1.913859
# (Epoch 6 / 50) train loss: 1.057238; val loss: 1.848151
# (Epoch 7 / 50) train loss: 0.954064; val loss: 1.796255
# (Epoch 8 / 50) train loss: 0.862584; val loss: 1.720778
# (Epoch 9 / 50) train loss: 0.783909; val loss: 1.673749
# (Epoch 10 / 50) train loss: 0.715176; val loss: 1.665820
# (Epoch 11 / 50) train loss: 0.651509; val loss: 1.642123
# (Epoch 12 / 50) train loss: 0.596634; val loss: 1.595122
# (Epoch 13 / 50) train loss: 0.548892; val loss: 1.563585
# (Epoch 14 / 50) train loss: 0.509299; val loss: 1.540522
# (Epoch 15 / 50) train loss: 0.469092; val loss: 1.521957
# (Epoch 16 / 50) train loss: 0.437260; val loss: 1.500908
# (Epoch 17 / 50) train loss: 0.407888; val loss: 1.490455
# (Epoch 18 / 50) train loss: 0.381894; val loss: 1.479446
# (Epoch 19 / 50) train loss: 0.358812; val loss: 1.462164
# (Epoch 20 / 50) train loss: 0.338494; val loss: 1.445006
# (Epoch 21 / 50) train loss: 0.317973; val loss: 1.425285
# (Epoch 22 / 50) train loss: 0.300351; val loss: 1.411373
# (Epoch 23 / 50) train loss: 0.285291; val loss: 1.398202
# (Epoch 24 / 50) train loss: 0.269116; val loss: 1.395081
# (Epoch 25 / 50) train loss: 0.255578; val loss: 1.385935
# (Epoch 26 / 50) train loss: 0.242839; val loss: 1.370438
# (Epoch 27 / 50) train loss: 0.231219; val loss: 1.359000
# (Epoch 28 / 50) train loss: 0.219620; val loss: 1.356199
# (Epoch 29 / 50) train loss: 0.209150; val loss: 1.349560
# (Epoch 30 / 50) train loss: 0.199847; val loss: 1.340493
# (Epoch 31 / 50) train loss: 0.191645; val loss: 1.336245
# (Epoch 32 / 50) train loss: 0.182846; val loss: 1.327798
# (Epoch 33 / 50) train loss: 0.175373; val loss: 1.323602
# (Epoch 34 / 50) train loss: 0.168469; val loss: 1.321800
# (Epoch 35 / 50) train loss: 0.161149; val loss: 1.322144
# (Epoch 36 / 50) train loss: 0.155475; val loss: 1.319482
# (Epoch 37 / 50) train loss: 0.150335; val loss: 1.314635
# (Epoch 38 / 50) train loss: 0.144224; val loss: 1.311410
# (Epoch 39 / 50) train loss: 0.139447; val loss: 1.310295
# (Epoch 40 / 50) train loss: 0.134700; val loss: 1.313186
# (Epoch 41 / 50) train loss: 0.130101; val loss: 1.312623
# (Epoch 42 / 50) train loss: 0.126355; val loss: 1.317293
# (Epoch 43 / 50) train loss: 0.122283; val loss: 1.308541
# (Epoch 44 / 50) train loss: 0.118783; val loss: 1.309766
# (Epoch 45 / 50) train loss: 0.115505; val loss: 1.317812
# (Epoch 46 / 50) train loss: 0.112218; val loss: 1.313601
# (Epoch 47 / 50) train loss: 0.108960; val loss: 1.309242
# (Epoch 48 / 50) train loss: 0.106164; val loss: 1.315811
# (Epoch 49 / 50) train loss: 0.103408; val loss: 1.320171
# (Epoch 50 / 50) train loss: 0.100873; val loss: 1.316397
# Best val loss of current config:1.316396713256836
#
# Evaluating Config #14 [of 40]:
#  {'num_layers': 0, 'reg': 7.773329826669335e-06, 'lr': 0.00010787200383663106, 'n_hidden': 256, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 2.254256; val loss: 2.493567
# (Epoch 2 / 50) train loss: 1.640125; val loss: 2.070458
# (Epoch 3 / 50) train loss: 1.308596; val loss: 1.911626
# (Epoch 4 / 50) train loss: 1.063804; val loss: 1.815262
# (Epoch 5 / 50) train loss: 0.933653; val loss: 1.736140
# (Epoch 6 / 50) train loss: 0.810912; val loss: 1.625600
# (Epoch 42 / 50) train loss: 0.038351; val loss: 1.220512
# (Epoch 43 / 50) train loss: 0.037266; val loss: 1.226460
# (Epoch 44 / 50) train loss: 0.036224; val loss: 1.227205
# Stopping early at epoch 43!
# Best val loss of current config:1.227205067873001
#
# Evaluating Config #16 [of 40]:
#  {'num_layers': 4, 'reg': 2.3398697850432014e-05, 'lr': 9.350902722324191e-06, 'n_hidden': 64, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 3.551174; val loss: 3.508917
# (Epoch 2 / 50) train loss: 3.441787; val loss: 3.451031
# (Epoch 3 / 50) train loss: 3.336946; val loss: 3.392652
# (Epoch 4 / 50) train loss: 3.234322; val loss: 3.333847
# (Epoch 5 / 50) train loss: 3.135646; val loss: 3.277366
# (Epoch 6 / 50) train loss: 3.033646; val loss: 3.223179
# (Epoch 7 / 50) train loss: 2.935652; val loss: 3.173332
# (Epoch 8 / 50) train loss: 2.842658; val loss: 3.126240
# (Epoch 9 / 50) train loss: 2.748570; val loss: 3.080298
# (Epoch 10 / 50) train loss: 2.664623; val loss: 3.036413
# (Epoch 11 / 50) train loss: 2.574766; val loss: 2.991817
# (Epoch 12 / 50) train loss: 2.499144; val loss: 2.948836
# (Epoch 13 / 50) train loss: 2.425655; val loss: 2.905334
# (Epoch 14 / 50) train loss: 2.361083; val loss: 2.863455
# (Epoch 15 / 50) train loss: 2.296182; val loss: 2.822083
# (Epoch 16 / 50) train loss: 2.234429; val loss: 2.782989
# (Epoch 17 / 50) train loss: 2.180221; val loss: 2.744498
# (Epoch 18 / 50) train loss: 2.127852; val loss: 2.707056
# (Epoch 19 / 50) train loss: 2.079240; val loss: 2.670978
# (Epoch 20 / 50) train loss: 2.034699; val loss: 2.635717
# (Epoch 21 / 50) train loss: 1.988861; val loss: 2.604808
# (Epoch 22 / 50) train loss: 1.947778; val loss: 2.574042
# (Epoch 23 / 50) train loss: 1.906686; val loss: 2.545165
# (Epoch 24 / 50) train loss: 1.869689; val loss: 2.515654
# (Epoch 25 / 50) train loss: 1.830709; val loss: 2.488535
# (Epoch 26 / 50) train loss: 1.794865; val loss: 2.461591
# (Epoch 27 / 50) train loss: 1.760096; val loss: 2.434582
# (Epoch 28 / 50) train loss: 1.725196; val loss: 2.409332
# (Epoch 29 / 50) train loss: 1.693023; val loss: 2.383987
# ...
# (Epoch 1 / 50) train loss: 2.823223; val loss: 3.114334
# (Epoch 2 / 50) train loss: 2.444177; val loss: 2.948613
# (Epoch 3 / 50) train loss: 2.173359; val loss: 2.809066
# (Epoch 4 / 50) train loss: 1.969645; val loss: 2.681454
# (Epoch 5 / 50) train loss: 1.819415; val loss: 2.570149
# (Epoch 6 / 50) train loss: 1.682868; val loss: 2.475440
# (Epoch 42 / 50) train loss: 0.266658; val loss: 1.433639
# (Epoch 43 / 50) train loss: 0.257357; val loss: 1.427294
# (Epoch 44 / 50) train loss: 0.249401; val loss: 1.422424
# (Epoch 45 / 50) train loss: 0.241142; val loss: 1.415675
# (Epoch 46 / 50) train loss: 0.233868; val loss: 1.411767
# (Epoch 47 / 50) train loss: 0.226657; val loss: 1.407316
# (Epoch 48 / 50) train loss: 0.220236; val loss: 1.402431
# (Epoch 49 / 50) train loss: 0.213596; val loss: 1.399485
# (Epoch 50 / 50) train loss: 0.207529; val loss: 1.395959
# Best val loss of current config:1.3959588557481766
#
# Evaluating Config #37 [of 40]:
#  {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 3.553205; val loss: 2.931890
# (Epoch 2 / 50) train loss: 2.558730; val loss: 2.230214
# (Epoch 3 / 50) train loss: 1.842506; val loss: 1.863976
# (Epoch 4 / 50) train loss: 1.435581; val loss: 1.653278
# (Epoch 5 / 50) train loss: 1.084126; val loss: 1.501502
# (Epoch 6 / 50) train loss: 0.820508; val loss: 1.327600
# (Epoch 7 / 50) train loss: 0.630685; val loss: 1.206644
# (Epoch 8 / 50) train loss: 0.496055; val loss: 1.142716
# (Epoch 9 / 50) train loss: 0.389397; val loss: 1.129308
# (Epoch 10 / 50) train loss: 0.319200; val loss: 1.111306
# (Epoch 11 / 50) train loss: 0.260689; val loss: 1.069550
# (Epoch 12 / 50) train loss: 0.214335; val loss: 1.057573
# (Epoch 13 / 50) train loss: 0.180324; val loss: 1.035893
# (Epoch 14 / 50) train loss: 0.153689; val loss: 1.012146
# (Epoch 15 / 50) train loss: 0.131578; val loss: 1.004567
# (Epoch 16 / 50) train loss: 0.115874; val loss: 1.012649
# (Epoch 17 / 50) train loss: 0.101801; val loss: 1.012869
# (Epoch 18 / 50) train loss: 0.091883; val loss: 0.988474
# (Epoch 19 / 50) train loss: 0.083262; val loss: 0.966927
# (Epoch 20 / 50) train loss: 0.075891; val loss: 0.974273
# (Epoch 21 / 50) train loss: 0.070080; val loss: 0.996974
# (Epoch 22 / 50) train loss: 0.065283; val loss: 0.989668
# (Epoch 23 / 50) train loss: 0.060678; val loss: 0.975950
# (Epoch 24 / 50) train loss: 0.057149; val loss: 0.964419
# (Epoch 25 / 50) train loss: 0.053908; val loss: 0.965762
# (Epoch 26 / 50) train loss: 0.051081; val loss: 0.976838
# (Epoch 27 / 50) train loss: 0.048540; val loss: 0.977687
# (Epoch 28 / 50) train loss: 0.046227; val loss: 0.973491
# (Epoch 29 / 50) train loss: 0.044095; val loss: 0.972141
# (Epoch 30 / 50) train loss: 0.042259; val loss: 0.976623
# (Epoch 31 / 50) train loss: 0.040487; val loss: 0.976018
# (Epoch 32 / 50) train loss: 0.038892; val loss: 0.976799
# (Epoch 33 / 50) train loss: 0.037428; val loss: 0.977308
# (Epoch 34 / 50) train loss: 0.036047; val loss: 0.977784
# (Epoch 35 / 50) train loss: 0.034747; val loss: 0.980145
# (Epoch 36 / 50) train loss: 0.033569; val loss: 0.983405
# (Epoch 37 / 50) train loss: 0.032457; val loss: 0.984571
# (Epoch 38 / 50) train loss: 0.031451; val loss: 0.984027
# (Epoch 39 / 50) train loss: 0.030458; val loss: 0.986691
# (Epoch 40 / 50) train loss: 0.029524; val loss: 0.988805
# (Epoch 41 / 50) train loss: 0.028664; val loss: 0.988734
# (Epoch 42 / 50) train loss: 0.027819; val loss: 0.993194
# (Epoch 43 / 50) train loss: 0.027040; val loss: 0.995835
# (Epoch 44 / 50) train loss: 0.026285; val loss: 0.996021
# (Epoch 45 / 50) train loss: 0.025586; val loss: 0.995238
# (Epoch 46 / 50) train loss: 0.024971; val loss: 0.997639
# (Epoch 47 / 50) train loss: 0.024294; val loss: 1.001798
# (Epoch 48 / 50) train loss: 0.023680; val loss: 1.006414
# Stopping early at epoch 47!
# Best val loss of current config:1.0064142793416977
#
# Evaluating Config #38 [of 40]:
#  {'num_layers': 12, 'reg': 1.518000596574052e-05, 'lr': 0.0006283128624290351, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 1.731350; val loss: 1.782676
# (Epoch 2 / 50) train loss: 0.908835; val loss: 1.409615
# (Epoch 3 / 50) train loss: 0.460059; val loss: 1.470869
# (Epoch 4 / 50) train loss: 0.232479; val loss: 1.298910
# (Epoch 5 / 50) train loss: 0.154261; val loss: 1.129170
# (Epoch 6 / 50) train loss: 0.083746; val loss: 1.248847
# (Epoch 7 / 50) train loss: 0.058105; val loss: 1.476748
# (Epoch 8 / 50) train loss: 0.045718; val loss: 1.478201
# (Epoch 9 / 50) train loss: 0.032449; val loss: 1.452845
# (Epoch 10 / 50) train loss: 0.028084; val loss: 1.421877
# (Epoch 11 / 50) train loss: 0.023014; val loss: 1.387510
# (Epoch 12 / 50) train loss: 0.019641; val loss: 1.368800
# (Epoch 13 / 50) train loss: 0.017382; val loss: 1.339127
# (Epoch 14 / 50) train loss: 0.015549; val loss: 1.304346
# (Epoch 15 / 50) train loss: 0.014074; val loss: 1.287404
# Stopping early at epoch 14!
# Best val loss of current config:1.2874035239219666
#
# Evaluating Config #39 [of 40]:
#  {'num_layers': 4, 'reg': 1.6209975555057282e-05, 'lr': 0.0007244454033814862, 'n_hidden': 256, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 1.809042; val loss: 1.763876
# (Epoch 2 / 50) train loss: 0.784986; val loss: 1.578205
# (Epoch 3 / 50) train loss: 0.393143; val loss: 1.425886
# (Epoch 4 / 50) train loss: 0.244787; val loss: 1.192338
# (Epoch 5 / 50) train loss: 0.127881; val loss: 1.238161
# (Epoch 6 / 50) train loss: 0.083967; val loss: 1.238965
# (Epoch 7 / 50) train loss: 0.057498; val loss: 1.117241
# (Epoch 8 / 50) train loss: 0.040500; val loss: 1.127981
# (Epoch 9 / 50) train loss: 0.032030; val loss: 1.146324
# (Epoch 10 / 50) train loss: 0.025926; val loss: 1.158982
# (Epoch 11 / 50) train loss: 0.021407; val loss: 1.159705
# (Epoch 12 / 50) train loss: 0.018487; val loss: 1.164834
# (Epoch 13 / 50) train loss: 0.016498; val loss: 1.168129
# (Epoch 14 / 50) train loss: 0.014779; val loss: 1.189277
# (Epoch 15 / 50) train loss: 0.013407; val loss: 1.201517
# (Epoch 16 / 50) train loss: 0.012258; val loss: 1.214261
# (Epoch 17 / 50) train loss: 0.011352; val loss: 1.227360
# (Epoch 18 / 50) train loss: 0.010665; val loss: 1.236996
# Stopping early at epoch 17!
# Best val loss of current config:1.2369957268238068
#
# Evaluating Config #40 [of 40]:
#  {'num_layers': 0, 'reg': 5.818960995873625e-06, 'lr': 1.8309892757734816e-06, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}
# (Epoch 1 / 50) train loss: 3.225726; val loss: 3.151737
# (Epoch 2 / 50) train loss: 3.213169; val loss: 3.144226
# (Epoch 3 / 50) train loss: 3.201532; val loss: 3.136943
# (Epoch 4 / 50) train loss: 3.189891; val loss: 3.129520
# (Epoch 5 / 50) train loss: 3.178085; val loss: 3.122406
# (Epoch 6 / 50) train loss: 3.166461; val loss: 3.115205
# (Epoch 7 / 50) train loss: 3.154821; val loss: 3.107960
# (Epoch 8 / 50) train loss: 3.142793; val loss: 3.100744
# (Epoch 9 / 50) train loss: 3.130826; val loss: 3.093590
# (Epoch 10 / 50) train loss: 3.119392; val loss: 3.086294
# (Epoch 11 / 50) train loss: 3.107104; val loss: 3.079177
# (Epoch 12 / 50) train loss: 3.095261; val loss: 3.072096
# (Epoch 13 / 50) train loss: 3.083251; val loss: 3.064994
# (Epoch 14 / 50) train loss: 3.071734; val loss: 3.057800
# (Epoch 15 / 50) train loss: 3.059507; val loss: 3.050875
# (Epoch 16 / 50) train loss: 3.047181; val loss: 3.043833
# (Epoch 17 / 50) train loss: 3.034885; val loss: 3.036856
# (Epoch 18 / 50) train loss: 3.023070; val loss: 3.029904
# (Epoch 19 / 50) train loss: 3.010334; val loss: 3.023062
# (Epoch 20 / 50) train loss: 2.998430; val loss: 3.016119
# (Epoch 21 / 50) train loss: 2.986226; val loss: 3.009178
# (Epoch 22 / 50) train loss: 2.974015; val loss: 3.002115
# (Epoch 23 / 50) train loss: 2.960674; val loss: 2.995325
# (Epoch 24 / 50) train loss: 2.948662; val loss: 2.988611
# (Epoch 25 / 50) train loss: 2.935989; val loss: 2.981818
# (Epoch 26 / 50) train loss: 2.923295; val loss: 2.975103
# (Epoch 27 / 50) train loss: 2.910248; val loss: 2.968407
# (Epoch 28 / 50) train loss: 2.897970; val loss: 2.961656
# (Epoch 29 / 50) train loss: 2.884669; val loss: 2.954993
# (Epoch 30 / 50) train loss: 2.871493; val loss: 2.948394
# (Epoch 31 / 50) train loss: 2.858847; val loss: 2.941690
# (Epoch 32 / 50) train loss: 2.845841; val loss: 2.935098
# (Epoch 33 / 50) train loss: 2.831519; val loss: 2.928549
# (Epoch 34 / 50) train loss: 2.819298; val loss: 2.922064
# (Epoch 35 / 50) train loss: 2.805170; val loss: 2.915569
# (Epoch 36 / 50) train loss: 2.792062; val loss: 2.909157
# (Epoch 37 / 50) train loss: 2.778548; val loss: 2.902681
# (Epoch 38 / 50) train loss: 2.763588; val loss: 2.896505
# (Epoch 39 / 50) train loss: 2.750065; val loss: 2.890258
# (Epoch 40 / 50) train loss: 2.736186; val loss: 2.883859
# (Epoch 41 / 50) train loss: 2.721974; val loss: 2.877658
# (Epoch 42 / 50) train loss: 2.707947; val loss: 2.871506
# (Epoch 43 / 50) train loss: 2.693182; val loss: 2.865351
# (Epoch 44 / 50) train loss: 2.679539; val loss: 2.859186
# (Epoch 45 / 50) train loss: 2.663944; val loss: 2.853259
# (Epoch 46 / 50) train loss: 2.649324; val loss: 2.847296
# (Epoch 47 / 50) train loss: 2.634606; val loss: 2.841364
# (Epoch 48 / 50) train loss: 2.619974; val loss: 2.835382
# (Epoch 49 / 50) train loss: 2.604693; val loss: 2.829544
# (Epoch 50 / 50) train loss: 2.590070; val loss: 2.823605
# Best val loss of current config:2.8236045837402344
#
# Search done. Best Val Loss = 0.9644188433885574
# Best Config: {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02}

# %%
best_model.eval()
with torch.no_grad():
    val_loss=0
    for X,y in iter(labled_val_loader):
        X=X.view(X.shape[0],-1).to(device)
        y=y.to(device)
        y_pred=best_model(X)
        loss=Loss(**best_config).to(device)
        val_loss+=loss.compute_loss_without_regularization(y_pred,y).item()
    val_loss/=len(labled_val_loader)
print(val_loss)
# Out:
# 0.9644188433885574

# %%
print("Finished training!")
print("How did we do? Let's check the accuracy of the defaut classifier on the training and validation sets:")
print(f"Training Acc: {best_model.getAcc(labled_train_loader)[1] * 100}%")
print(f"Validation Acc: {best_model.getAcc(labled_val_loader)[1] * 100}%")
# Out:
# Finished training!
# How did we do? Let's check the accuracy of the defaut classifier on the training and validation sets:
# Training Acc: 100.0%
# Validation Acc: 74.0%

# %% [markdown]
# # 3. Autoencoder
#
# With only a limited number of labeled images, it's challenging to achieve high performance. We have no money left to pay the student to create more labels, and labeling the data ourselves is out of question. A commonly used approach would be to apply data augmentation to maximize the potential of our limited labeled data, but here we provide another way to solve this problem: **transfer learning**.
#
# For each input, the autoencoder tries to reproduce the same image as an output. The difficulty behind this task is that the autoencoder has to go through a low dimensional bottleneck, which is called the **latent space**.
# In other words, the autoencoder learns to represent all the input information in a low dimensional latent space - it learns to compress the input distribution. To train the autoencoder, we use the mean squared error loss, which calculates the discrepancy between the input pixels and the output pixels. The best part is that this loss function doesn't require any labels!
#
# By pretraining the autoencoder in this way on a large amount of unlabeled data, we can capture valuable latent representations of the input images. Then, we transfer the weights of the encoder to our classifier, enabling it to benefit from the knowledge learned during the unsupervised pretraining phase.
#
# <!-- In case the image does not show, uncomment the following:
# ![autoencoder](img/autoencoder.png)
# -->
# <img name="autoencoder" src="https://i2dl.vc.in.tum.de/static/images/exercise_08/autoencoder.png">
#
# After this, our encoder has learned to extract meaningful information from the inputs. We can then transfer its weights
# to a classifier architecture and finetune it with our labeled data, i.e., instead of initializing our encoder randomly, we are re-using the weights of our trained encoder from our autoencoder network.
#
# <!-- In case the image does not show, uncomment the following:
# ![autoencoder_pretrained](img/pretrained.png)
# -->
# <img name="autoencoder_pretrained" src="https://i2dl.vc.in.tum.de/static/images/exercise_08/pretrained.png">
#
#
# Before we can train our autoencoder, you have to initialize your `decoder` architecture. The simplest way is to mirror your encoder architecture, which ensures that the `latent space` output of our `encoder` is correctly transformed to our input shape.
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>Decoder</code> class initialization in <code>exercise_code/models.py</code>.</p>
#     <p>Implement <code>forward</code>, <code>set_optimizer</code>, <code>training_step</code> and <code>validation_step</code> of the <code>Autoencoder</code> in  <code>exercise_code/models.py</code>, following the pipeline we've shown you in train_classifier().</p>
#     <p>Note the differences between the classification task and now the regression task!</p>
#
#
# </div>
#
# ## 3.2 Autoencoder Training
#
# Now, we can train the full autoencoder consisting of both en- and decoder.

# %%
from exercise_code.models import Autoencoder, Encoder, Decoder

########################################################################
# TODO: Define your hyperparameters here!                              #
# Hint: use a large batch_size                                         #
########################################################################
hparams= None
hparams_end=best_config

hparams_dec = {
    "output_dim": 28*28,
    "batch_size": 25,
    "num_layers": 3,
    "lr": 3e-4,
    "reg": 4e-5,
    "n_hidden": 2**7,
    "num_workers": 10,
    "latent_dim": 20,
    "device": "mps",
    "batch_norm": False,
    "layer_norm": True,
    "shortcut": True,
    "epochs": 50,
    "optimizer": "ADAM",
    "loss_function": torch.nn.CrossEntropyLoss(),
    "patience": 10,
    "patience_delta": 0.02
}
hparams_auto = {
    "batch_size": 2**10,
    "lr": 3e-4,
    "reg": 4e-5,
    "n_hidden": 2**7,
    "num_workers": 10,
    "latent_dim": 20,
    "device": "mps",
    "batch_norm": False,
    "layer_norm": True,
    "shortcut": True,
    "epochs": 15,
    "optimizer": "ADAM",
    "loss_function": torch.nn.MSELoss(),
    "patience": 10,
    "patience_delta": 0.02
}

########################################################################
#                           END OF YOUR CODE                           #
########################################################################
encoder_pretrained = Encoder(hparams_end).to(device)
decoder = Decoder(hparams_dec).to(device)
autoencoder = Autoencoder(hparams_auto, encoder_pretrained, decoder).to(device)

# %% [markdown]
# Some tests to check whether we'll accept your model.

# %%
from exercise_code.Util import printModelInfo, load_model
_ = printModelInfo(autoencoder)
# Out:
# # Paramters: Your model has 1.659 mio. params.
# Model accepted!

# %% [markdown]
# After implementing the relevant functions - read the following code, and then run it.
# Keep in mind that an epoch here will take much longer since
# we are iterating through 5,8600 images instead of just 100.
#
# For speed, colab is indeed recommended.

# %%
from exercise_code.loss import LossAuto
encoder_pretrained = Encoder(hparams_end).to(device)
decoder = Decoder(hparams_dec).to(device)
autoencoder = Autoencoder(hparams_auto, encoder_pretrained, decoder).to(device)

def train_model(model, train_loader, val_loader, loss_func, tb_logger, epochs=10, name='Autoencoder'):
    
    optimizer = model.optimizer
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=epochs * len(train_loader) / 5, gamma=0.7)
    validation_loss = 0
    model = model.to(device)
    for epoch in range(epochs):
        
        # Train
        training_loop = create_tqdm_bar(train_loader, desc=f'Training Epoch [{epoch}/{epochs}]')
        training_loss = 0
        for train_iteration, batch in training_loop:
            
            loss = model.training_step(batch, loss_func) # You need to implement this function.
            training_loss += loss.item()
            scheduler.step()

            # Update the progress bar.
            training_loop.set_postfix(train_loss = "{:.8f}".format(training_loss / (train_iteration + 1)), val_loss = "{:.8f}".format(validation_loss))

            # Update the tensorboard logger.
            tb_logger.add_scalar(f'{name}/train_loss', loss.item(), epoch * len(train_loader) + train_iteration)

        # Validation
        val_loop = create_tqdm_bar(val_loader, desc=f'Validation Epoch [{epoch}/{epochs}]')
        validation_loss = 0
        with torch.no_grad():
            for val_iteration, batch in val_loop:
                loss = model.validation_step(batch, loss_func) # You need to implement this function.
                validation_loss += loss.item()

                # Update the progress bar.
                val_loop.set_postfix(val_loss = "{:.8f}".format(validation_loss / (val_iteration + 1)))

                # Update the tensorboard logger.
                tb_logger.add_scalar(f'{name}/val_loss', validation_loss / (val_iteration + 1), epoch * len(val_loader) + val_iteration)
        # This value is for the progress bar of the training loop.
        validation_loss /= len(val_loader)

# Create a tensorboard logger.
# NOTE: In order to see the logs, run the following command in the terminal: tensorboard --logdir=./
# Also, in order to reset the logs, delete the logs folder MANUALLY.

path = os.path.join('logs', 'ae_logs')
num_of_runs = len(os.listdir(path)) if os.path.exists(path) else 0
path = os.path.join(path, f'run_{num_of_runs + 1}')
tb_logger = SummaryWriter(path)

# Train the classifier.
unlabled_train_loader = torch.utils.data.DataLoader(unlabeled_train, batch_size=hparams_auto['batch_size'], shuffle=True)
unlabled_val_loader = torch.utils.data.DataLoader(unlabeled_val, batch_size=hparams_auto['batch_size'], shuffle=False)

epochs = hparams_auto.get('epochs', 5)
loss_func = Loss(**hparams_auto) # The loss function we use for regression (Could also be nn.L1Loss()).
train_model(autoencoder, unlabled_train_loader, unlabled_val_loader, loss_func, tb_logger, epochs=epochs, name='Autoencoder')

print("Finished training!")
# Out:
# Training Epoch [0/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  5.98it/s, train_loss=0.45766037, val_loss=0.00000000]
# Validation Epoch [0/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.29it/s, val_loss=0.26243499]
# Training Epoch [1/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  6.08it/s, train_loss=0.24638914, val_loss=0.26243499]
# Validation Epoch [1/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.70it/s, val_loss=0.22585467]
# Training Epoch [2/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  5.95it/s, train_loss=0.20325840, val_loss=0.22585467]
# Validation Epoch [2/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.70it/s, val_loss=0.18229324]
# Training Epoch [3/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  5.97it/s, train_loss=0.17049172, val_loss=0.18229324]
# Validation Epoch [3/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 23.42it/s, val_loss=0.16148333]
# Training Epoch [4/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  5.95it/s, train_loss=0.15274787, val_loss=0.16148333]
# Validation Epoch [4/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.79it/s, val_loss=0.14664331]
# Training Epoch [5/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  5.92it/s, train_loss=0.13963650, val_loss=0.14664331]
# Validation Epoch [5/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.66it/s, val_loss=0.13503292]
# Training Epoch [6/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  6.06it/s, train_loss=0.13025980, val_loss=0.13503292]
# Validation Epoch [6/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.48it/s, val_loss=0.12793058]
# Training Epoch [7/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  6.06it/s, train_loss=0.12367848, val_loss=0.12793058]
# Validation Epoch [7/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.96it/s, val_loss=0.12178189]
# Training Epoch [8/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  6.08it/s, train_loss=0.11788869, val_loss=0.12178189]
# Validation Epoch [8/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.61it/s, val_loss=0.11632553]
# Training Epoch [9/15]: 100%|██████████████████████████████████████████████| 58/58 [00:09<00:00,  6.01it/s, train_loss=0.11341995, val_loss=0.11632553]
# Validation Epoch [9/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 23.07it/s, val_loss=0.11290412]
# Training Epoch [10/15]: 100%|█████████████████████████████████████████████| 58/58 [00:09<00:00,  6.04it/s, train_loss=0.11021225, val_loss=0.11290412]
# Validation Epoch [10/15]: 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.53it/s, val_loss=0.10979558]
# Training Epoch [11/15]: 100%|█████████████████████████████████████████████| 58/58 [00:09<00:00,  5.93it/s, train_loss=0.10723661, val_loss=0.10979558]
# Validation Epoch [11/15]: 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 20.16it/s, val_loss=0.10700125]
# Training Epoch [12/15]: 100%|█████████████████████████████████████████████| 58/58 [00:09<00:00,  5.96it/s, train_loss=0.10484318, val_loss=0.10700125]
# Validation Epoch [12/15]: 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.01it/s, val_loss=0.10512231]
# Training Epoch [13/15]: 100%|█████████████████████████████████████████████| 58/58 [00:09<00:00,  5.98it/s, train_loss=0.10306637, val_loss=0.10512231]
# Validation Epoch [13/15]: 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.73it/s, val_loss=0.10334485]
# Training Epoch [14/15]: 100%|█████████████████████████████████████████████| 58/58 [00:09<00:00,  6.02it/s, train_loss=0.10136181, val_loss=0.10334485]
# Validation Epoch [14/15]: 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.65it/s, val_loss=0.10169409]
# Finished training!

# %% [markdown]
# Once trained, let's have a look at the reconstructed validation images (If you have not already looked at them in TensorBoard).

# %%
reconstructions = autoencoder.getReconstructions(unlabled_val_loader)
for i in range(64):
    plt.subplot(8,8,i+1)
    plt.axis('off')
    plt.imshow(reconstructions[i], cmap='gray', interpolation='none')
    
plt.tight_layout()

# %% [markdown]
# ## 3.3 Hyperparameter Tuning

# %%
class MyAutoEnc(Autoencoder):
    def __init__(self, hparams):
        super().__init__(hparams, Encoder(hparams["encoder_hparams"]), Decoder(hparams["decoder_hparams"]))
        # set hyperparams
        self.hparams = hparams
        self.device = hparams.get("device", torch.device("cuda" if torch.cuda.is_available() else "cpu"))
        self.set_optimizer()

# %%
best_config_enc=best_config
best_config_dec=best_config
best_config_dec["output_dim"]=28*28
hparams_auto={
    "encoder_hparams": best_config_enc,
    "decoder_hparams": best_config_dec,
    "batch_size": 2**10,
    "lr": 3e-4,
    "reg": 4e-5,
    "n_hidden": 2**7,
    "num_workers": 10,
    "device": "mps",
    "epochs": 15,
    "optimizer": "ADAM",
    "loss_func": torch.nn.MSELoss(),
    "patience": 4,
    "patience_delta": 0.02,
}

# %%
class DuplicateDataset(ImageFolderDataset):
    def __init__(self, unlabeledset):
        self.unlabeledset = unlabeledset

    def __len__(self):
        return len(self.unlabeledset)

    def __getitem__(self, idx):
        feature = self.unlabeledset[idx]  # Get the feature vector
        return feature, feature     # Return the same value for feature and target

# %%
labeled_train=DuplicateDataset(unlabeled_train)
labeled_val=DuplicateDataset(unlabeled_val)

# %%
from exercise_code.hyperparameter_tuning import random_search
from torch.utils.data import DataLoader, Subset


# Define the number of samples you want
num_samples_train = 1000
num_samples_val = 750

# Define the dataloader for hyperparameter tuning

labeled_train_hparams_tuning=Subset(labeled_train, range(num_samples_train))
labeled_val_hparams_tuning=Subset(labeled_val, range(num_samples_val))

num_searches=10

new_config={
        "reg": ([1e-3, 1e-6], "log"),
        "lr": ([1e-3,1e-6], "log"),
        "batch_size": ([2**6,2**8,2**9], "item")
    }

for key,value in hparams_auto.items():
    if key not in (new_config):
        new_config[key]=([value],"item")


best_model, best_config, results  = random_search(
    labeled_train_hparams_tuning, labeled_val_hparams_tuning,
    random_search_spaces = new_config,
    model=MyAutoEnc,
    num_search = num_searches)
# Out:
# Evaluating Config #1 [of 10]:
#  {'reg': 0.0005930094797291455, 'lr': 3.0946008811767415e-05, 'batch_size': 256, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 1.191061; val loss: 1.108108
# (Epoch 2 / 15) train loss: 1.070966; val loss: 1.019211
# (Epoch 3 / 15) train loss: 0.995972; val loss: 0.959060
# (Epoch 4 / 15) train loss: 0.939289; val loss: 0.909680
# (Epoch 5 / 15) train loss: 0.894499; val loss: 0.871315
# (Epoch 6 / 15) train loss: 0.859325; val loss: 0.841409
# (Epoch 7 / 15) train loss: 0.831645; val loss: 0.816911
# (Epoch 8 / 15) train loss: 0.808221; val loss: 0.795153
# (Epoch 9 / 15) train loss: 0.787211; val loss: 0.775617
# (Epoch 10 / 15) train loss: 0.768376; val loss: 0.757941
# (Epoch 11 / 15) train loss: 0.751201; val loss: 0.741678
# (Epoch 12 / 15) train loss: 0.735206; val loss: 0.726260
# (Epoch 13 / 15) train loss: 0.719896; val loss: 0.711431
# (Epoch 14 / 15) train loss: 0.705231; val loss: 0.697095
# (Epoch 15 / 15) train loss: 0.690924; val loss: 0.683112
# Best val loss of current config:0.6831116278966268
#
# Evaluating Config #2 [of 10]:
#  {'reg': 1.0578239200776615e-06, 'lr': 2.077618186217754e-06, 'batch_size': 256, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 1.276103; val loss: 1.264507
# (Epoch 2 / 15) train loss: 1.260159; val loss: 1.247999
# (Epoch 3 / 15) train loss: 1.243922; val loss: 1.231264
# (Epoch 4 / 15) train loss: 1.227357; val loss: 1.214460
# (Epoch 5 / 15) train loss: 1.210899; val loss: 1.197791
# (Epoch 6 / 15) train loss: 1.194674; val loss: 1.181398
# (Epoch 7 / 15) train loss: 1.178535; val loss: 1.165444
# (Epoch 8 / 15) train loss: 1.162681; val loss: 1.150038
# (Epoch 9 / 15) train loss: 1.147573; val loss: 1.135258
# (Epoch 10 / 15) train loss: 1.132959; val loss: 1.121142
# (Epoch 11 / 15) train loss: 1.118905; val loss: 1.107662
# (Epoch 12 / 15) train loss: 1.105461; val loss: 1.094813
# (Epoch 13 / 15) train loss: 1.092627; val loss: 1.082547
# (Epoch 14 / 15) train loss: 1.080320; val loss: 1.070841
# (Epoch 15 / 15) train loss: 1.068743; val loss: 1.059630
# Best val loss of current config:1.0596298376719158
#
# Evaluating Config #3 [of 10]:
#  {'reg': 4.887135813296396e-06, 'lr': 0.0008257617491122168, 'batch_size': 64, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 0.578062; val loss: 0.296440
# (Epoch 2 / 15) train loss: 0.284039; val loss: 0.277407
# (Epoch 3 / 15) train loss: 0.272351; val loss: 0.269531
# (Epoch 4 / 15) train loss: 0.268794; val loss: 0.268950
# (Epoch 5 / 15) train loss: 0.268269; val loss: 0.268976
# (Epoch 6 / 15) train loss: 0.268662; val loss: 0.268565
# (Epoch 7 / 15) train loss: 0.267688; val loss: 0.267520
# (Epoch 8 / 15) train loss: 0.264762; val loss: 0.263995
# (Epoch 9 / 15) train loss: 0.258440; val loss: 0.252572
# (Epoch 10 / 15) train loss: 0.243391; val loss: 0.237266
# (Epoch 11 / 15) train loss: 0.226294; val loss: 0.219144
# (Epoch 12 / 15) train loss: 0.208810; val loss: 0.202960
# (Epoch 13 / 15) train loss: 0.193932; val loss: 0.187994
# (Epoch 14 / 15) train loss: 0.179643; val loss: 0.174541
# (Epoch 15 / 15) train loss: 0.168800; val loss: 0.164551
# Best val loss of current config:0.1645511438449224
#
# Evaluating Config #4 [of 10]:
#  {'reg': 7.83888510646276e-05, 'lr': 8.872305754781808e-06, 'batch_size': 512, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 1.264377; val loss: 1.238910
# (Epoch 2 / 15) train loss: 1.230235; val loss: 1.206141
# (Epoch 3 / 15) train loss: 1.198474; val loss: 1.176694
# (Epoch 4 / 15) train loss: 1.170520; val loss: 1.151316
# (Epoch 5 / 15) train loss: 1.146668; val loss: 1.129846
# (Epoch 6 / 15) train loss: 1.126524; val loss: 1.111583
# (Epoch 7 / 15) train loss: 1.109281; val loss: 1.095549
# (Epoch 8 / 15) train loss: 1.093898; val loss: 1.080848
# (Epoch 9 / 15) train loss: 1.079532; val loss: 1.066837
# (Epoch 10 / 15) train loss: 1.065682; val loss: 1.053171
# (Epoch 11 / 15) train loss: 1.052051; val loss: 1.039772
# (Epoch 12 / 15) train loss: 1.038640; val loss: 1.026723
# (Epoch 13 / 15) train loss: 1.025646; val loss: 1.014132
# (Epoch 14 / 15) train loss: 1.013095; val loss: 1.002080
# (Epoch 15 / 15) train loss: 1.001017; val loss: 0.990566
# Best val loss of current config:0.9905664026737213
#
# Evaluating Config #5 [of 10]:
#  {'reg': 0.00022423463491966027, 'lr': 9.504234062493536e-05, 'batch_size': 256, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 1.103205; val loss: 0.962146
# (Epoch 2 / 15) train loss: 0.916324; val loss: 0.855727
# (Epoch 3 / 15) train loss: 0.829609; val loss: 0.792515
# (Epoch 4 / 15) train loss: 0.773435; val loss: 0.744228
# (Epoch 5 / 15) train loss: 0.727294; val loss: 0.700760
# (Epoch 6 / 15) train loss: 0.685078; val loss: 0.660468
# (Epoch 7 / 15) train loss: 0.645847; val loss: 0.622811
# (Epoch 8 / 15) train loss: 0.608966; val loss: 0.587427
# (Epoch 9 / 15) train loss: 0.574484; val loss: 0.554515
# (Epoch 10 / 15) train loss: 0.542550; val loss: 0.524375
# (Epoch 11 / 15) train loss: 0.513259; val loss: 0.496705
# (Epoch 12 / 15) train loss: 0.486550; val loss: 0.471356
# (Epoch 13 / 15) train loss: 0.461891; val loss: 0.448184
# (Epoch 14 / 15) train loss: 0.439574; val loss: 0.427031
# (Epoch 15 / 15) train loss: 0.418916; val loss: 0.407868
# Best val loss of current config:0.4078678985436757
#
# Evaluating Config #6 [of 10]:
#  {'reg': 3.516245037407235e-05, 'lr': 0.0002782757793149527, 'batch_size': 64, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 0.794360; val loss: 0.534520
# (Epoch 2 / 15) train loss: 0.419249; val loss: 0.329151
# (Epoch 3 / 15) train loss: 0.296139; val loss: 0.274858
# (Epoch 4 / 15) train loss: 0.266806; val loss: 0.261406
# (Epoch 5 / 15) train loss: 0.257451; val loss: 0.253983
# (Epoch 6 / 15) train loss: 0.249496; val loss: 0.245597
# (Epoch 7 / 15) train loss: 0.240654; val loss: 0.235912
# (Epoch 8 / 15) train loss: 0.230463; val loss: 0.225600
# (Epoch 9 / 15) train loss: 0.219587; val loss: 0.214995
# (Epoch 10 / 15) train loss: 0.208829; val loss: 0.205394
# (Epoch 11 / 15) train loss: 0.198295; val loss: 0.195085
# (Epoch 12 / 15) train loss: 0.188679; val loss: 0.186778
# (Epoch 13 / 15) train loss: 0.180124; val loss: 0.179042
# (Epoch 14 / 15) train loss: 0.172599; val loss: 0.172312
# (Epoch 15 / 15) train loss: 0.166101; val loss: 0.166035
# Best val loss of current config:0.16603474194804826
#
# Evaluating Config #7 [of 10]:
#  {'reg': 1.7602883576999254e-05, 'lr': 9.483375809486322e-05, 'batch_size': 512, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 1.174241; val loss: 1.057719
# (Epoch 2 / 15) train loss: 1.038268; val loss: 0.980956
# (Epoch 3 / 15) train loss: 0.965350; val loss: 0.922056
# (Epoch 4 / 15) train loss: 0.910672; val loss: 0.878495
# (Epoch 5 / 15) train loss: 0.869880; val loss: 0.845620
# (Epoch 6 / 15) train loss: 0.838723; val loss: 0.818405
# (Epoch 7 / 15) train loss: 0.812034; val loss: 0.792838
# (Epoch 8 / 15) train loss: 0.786782; val loss: 0.768586
# (Epoch 9 / 15) train loss: 0.762833; val loss: 0.745515
# (Epoch 10 / 15) train loss: 0.739860; val loss: 0.723173
# (Epoch 11 / 15) train loss: 0.717648; val loss: 0.701518
# (Epoch 12 / 15) train loss: 0.696096; val loss: 0.680636
# (Epoch 13 / 15) train loss: 0.675377; val loss: 0.660508
# (Epoch 14 / 15) train loss: 0.655431; val loss: 0.640997
# (Epoch 15 / 15) train loss: 0.636081; val loss: 0.622055
# Best val loss of current config:0.6220552027225494
#
# Evaluating Config #8 [of 10]:
#  {'reg': 8.8844524084993e-05, 'lr': 5.1582426946083896e-05, 'batch_size': 64, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 0.960823; val loss: 0.819266
# (Epoch 2 / 15) train loss: 0.754981; val loss: 0.697150
# (Epoch 3 / 15) train loss: 0.652776; val loss: 0.607985
# (Epoch 4 / 15) train loss: 0.570981; val loss: 0.534218
# (Epoch 5 / 15) train loss: 0.503514; val loss: 0.473649
# (Epoch 6 / 15) train loss: 0.448863; val loss: 0.424651
# (Epoch 7 / 15) train loss: 0.403942; val loss: 0.385153
# (Epoch 8 / 15) train loss: 0.368476; val loss: 0.353693
# (Epoch 9 / 15) train loss: 0.340031; val loss: 0.328721
# (Epoch 10 / 15) train loss: 0.317604; val loss: 0.309129
# (Epoch 11 / 15) train loss: 0.299901; val loss: 0.293527
# (Epoch 12 / 15) train loss: 0.286059; val loss: 0.281213
# (Epoch 13 / 15) train loss: 0.274786; val loss: 0.271570
# (Epoch 14 / 15) train loss: 0.265969; val loss: 0.263733
# (Epoch 15 / 15) train loss: 0.259119; val loss: 0.257339
# Best val loss of current config:0.2573386567334334
#
# Evaluating Config #9 [of 10]:
#  {'reg': 0.0004978250069744879, 'lr': 2.045164599634308e-06, 'batch_size': 512, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 1.233338; val loss: 1.228572
# (Epoch 2 / 15) train loss: 1.227183; val loss: 1.222506
# (Epoch 3 / 15) train loss: 1.221072; val loss: 1.216512
# (Epoch 4 / 15) train loss: 1.215064; val loss: 1.210600
# (Epoch 5 / 15) train loss: 1.209149; val loss: 1.204780
# (Epoch 6 / 15) train loss: 1.203303; val loss: 1.199061
# (Epoch 7 / 15) train loss: 1.197572; val loss: 1.193447
# (Epoch 8 / 15) train loss: 1.191964; val loss: 1.187944
# (Epoch 9 / 15) train loss: 1.186456; val loss: 1.182552
# (Epoch 10 / 15) train loss: 1.181034; val loss: 1.177275
# (Epoch 11 / 15) train loss: 1.175739; val loss: 1.172110
# (Epoch 12 / 15) train loss: 1.170639; val loss: 1.167058
# (Epoch 13 / 15) train loss: 1.165558; val loss: 1.162119
# (Epoch 14 / 15) train loss: 1.160578; val loss: 1.157289
# (Epoch 15 / 15) train loss: 1.155716; val loss: 1.152565
# Best val loss of current config:1.1525647044181824
#
# Evaluating Config #10 [of 10]:
#  {'reg': 0.00021636854091245137, 'lr': 1.1096938075762887e-05, 'batch_size': 64, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}
# (Epoch 1 / 15) train loss: 1.135652; val loss: 1.048905
# (Epoch 2 / 15) train loss: 0.995790; val loss: 0.944514
# (Epoch 3 / 15) train loss: 0.908961; val loss: 0.875820
# (Epoch 4 / 15) train loss: 0.851059; val loss: 0.829673
# (Epoch 5 / 15) train loss: 0.811351; val loss: 0.795749
# (Epoch 6 / 15) train loss: 0.780254; val loss: 0.767755
# (Epoch 7 / 15) train loss: 0.753836; val loss: 0.742915
# (Epoch 8 / 15) train loss: 0.730024; val loss: 0.720049
# (Epoch 9 / 15) train loss: 0.707778; val loss: 0.698543
# (Epoch 10 / 15) train loss: 0.686868; val loss: 0.678079
# (Epoch 11 / 15) train loss: 0.666868; val loss: 0.658607
# (Epoch 12 / 15) train loss: 0.647788; val loss: 0.639891
# (Epoch 13 / 15) train loss: 0.629338; val loss: 0.621970
# (Epoch 14 / 15) train loss: 0.611568; val loss: 0.604747
# (Epoch 15 / 15) train loss: 0.594787; val loss: 0.588247
# Best val loss of current config:0.588246688246727
#
# Search done. Best Val Loss = 0.1645511438449224
# Best Config: {'reg': 4.887135813296396e-06, 'lr': 0.0008257617491122168, 'batch_size': 64, 'encoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'decoder_hparams': {'num_layers': 8, 'reg': 3.809589132579565e-05, 'lr': 0.00019149831505821133, 'n_hidden': 128, 'input_size': 784, 'batch_size': 25, 'num_classes': 10, 'num_workers': 10, 'latent_dim': 20, 'device': 'mps', 'batch_norm': False, 'layer_norm': True, 'shortcut': True, 'epochs': 50, 'optimizer': 'ADAM', 'loss_function': CrossEntropyLoss(), 'patience': 10, 'patience_delta': 0.02, 'output_dim': 784}, 'n_hidden': 128, 'num_workers': 10, 'device': 'mps', 'epochs': 15, 'optimizer': 'ADAM', 'loss_func': MSELoss(), 'patience': 4, 'patience_delta': 0.02}

# %%
train_model(best_model, unlabled_train_loader, unlabled_val_loader, loss_func, tb_logger, epochs=epochs, name='Autoencoder')
print("Finished training!")
# Out:
# Training Epoch [0/15]: 100%|██████████████████████████████████████████████| 58/58 [00:13<00:00,  4.39it/s, train_loss=0.18753932, val_loss=0.00000000]
# Validation Epoch [0/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.85it/s, val_loss=0.15481465]
# Training Epoch [1/15]: 100%|██████████████████████████████████████████████| 58/58 [00:12<00:00,  4.53it/s, train_loss=0.14353414, val_loss=0.15481465]
# Validation Epoch [1/15]: 100%|█████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,
100%|████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.45it/s, val_loss=0.06603730]
# Finished training!

# %%
reconstructions = best_model.getReconstructions(unlabled_val_loader)
for i in range(64):
    plt.subplot(8,8,i+1)
    plt.axis('off')
    plt.imshow(reconstructions[i], cmap='gray', interpolation='none')
    
plt.tight_layout()

# %% [markdown]
# # 4. Transfer Learning
#
# ## 4.1 The pretrained Classifier
#
# Now we initialize another classifier but this time with the pretrained encoder.

# %%
from exercise_code.models import Classifier
from copy import deepcopy

hparams = {}
########################################################################
# TODO: Define your hyperparameters here!                             #
########################################################################

hparams=best_config_enc

########################################################################
#                           END OF YOUR CODE                           #
########################################################################

encoder_pretrained_copy = deepcopy(best_model.encoder)
classifier_pretrained = Classifier(hparams, encoder_pretrained_copy).to(device)

# %% [markdown]
# Let's define another trainer that will utilize the pretrained classifier, allowing us to compare its performance with the classifier trained only on the labeled data. To achieve a reasonable result, you may need to optimize the parameters you defined earlier.

# %%
# Create a tensorboard logger.
# NOTE: In order to see the logs, run the following command in the terminal: tensorboard --logdir=./
# Also, in order to reset the logs, delete the logs folder MANUALLY.
# Pay attention that if you run this cell mutltiple times, the pretrained_encoder
# is not reset, and will keep training from where it stopped. Thus, it could overfit.

path = os.path.join('logs', 'pretrained_cls_logs')
num_of_runs = len(os.listdir(path)) if os.path.exists(path) else 0
path = os.path.join(path, f'run_{num_of_runs + 1}')
tb_logger = SummaryWriter(path)

batch_size = hparams.get('batch_size', 16)
labled_train_loader = torch.utils.data.DataLoader(train_100_dataset, batch_size=batch_size, shuffle=True)
labled_val_loader = torch.utils.data.DataLoader(val_100_dataset, batch_size=batch_size, shuffle=False)

epochs = hparams.get('epochs', 20)
loss_func = Loss(loss_func=nn.CrossEntropyLoss()) # The loss function we use for classification.
train_classifier(classifier_pretrained, labled_train_loader, labled_val_loader, loss_func, tb_logger, epochs=epochs, name='Pretrained')

print("Finished training!")
# Out:
# Training Epoch [1/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  7.38it/s, curr_train_loss=2.45632178, val_loss=0.00000000]
# Validation Epoch [1/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 39.90it/s, val_loss=2.36054844]
# Training Epoch [2/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  9.85it/s, curr_train_loss=2.34213227, val_loss=2.36054844]
# Validation Epoch [2/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.58it/s, val_loss=2.34431142]
# Training Epoch [3/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  9.59it/s, curr_train_loss=2.29020905, val_loss=2.34431142]
# Validation Epoch [3/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 38.86it/s, val_loss=2.34126341]
# Training Epoch [4/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  9.87it/s, curr_train_loss=2.25218195, val_loss=2.34126341]
# Validation Epoch [4/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.16it/s, val_loss=2.33945322]
# Training Epoch [5/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  9.87it/s, curr_train_loss=2.21861422, val_loss=2.33945322]
# Validation Epoch [5/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 39.06it/s, val_loss=2.33799034]
# Training Epoch [6/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  9.90it/s, curr_train_loss=2.18831927, val_loss=2.33799034]
# Validation Epoch [6/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 38.88it/s, val_loss=2.32927257]
# Training Epoch [7/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  9.86it/s, curr_train_loss=2.15846229, val_loss=2.32927257]
# Validation Epoch [7/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.52it/s, val_loss=2.32094353]
# Training Epoch [8/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  9.86it/s, curr_train_loss=2.11901039, val_loss=2.32094353]
# Validation Epoch [8/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 39.67it/s, val_loss=2.30519813]
# Training Epoch [9/50]: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00,  9.55it/s, curr_train_loss=2.08756375, val_loss=2.30519813]
# Validation Epoch [9/50]: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 20.46it/s, val_loss=2.28339076]
# Training Epoch [10/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.75it/s, curr_train_loss=2.04104802, val_loss=2.28339076]
# Validation Epoch [10/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 33.69it/s, val_loss=2.25115007]
# Training Epoch [11/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.86it/s, curr_train_loss=1.97827584, val_loss=2.25115007]
# Validation Epoch [11/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.11it/s, val_loss=2.19903409]
# Training Epoch [12/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.95it/s, curr_train_loss=1.89873597, val_loss=2.19903409]
# Validation Epoch [12/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 38.78it/s, val_loss=2.12864763]
# Training Epoch [13/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.84it/s, curr_train_loss=1.78336027, val_loss=2.12864763]
# Validation Epoch [13/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.52it/s, val_loss=2.03039956]
# Training Epoch [14/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.93it/s, curr_train_loss=1.61453548, val_loss=2.03039956]
# Validation Epoch [14/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.05it/s, val_loss=1.87848616]
# Training Epoch [15/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.50it/s, curr_train_loss=1.40453196, val_loss=1.87848616]
# Validation Epoch [15/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 38.67it/s, val_loss=1.70051017]
# Training Epoch [16/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.96it/s, curr_train_loss=1.16016673, val_loss=1.70051017]
# Validation Epoch [16/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.15it/s, val_loss=1.57045108]
# Training Epoch [17/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.95it/s, curr_train_loss=1.04591332, val_loss=1.57045108]
# Validation Epoch [17/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 37.79it/s, val_loss=1.49545175]
# Training Epoch [18/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.97it/s, curr_train_loss=0.96112913, val_loss=1.49545175]
# Validation Epoch [18/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.91it/s, val_loss=1.45023313]
# Training Epoch [19/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00, 10.11it/s, curr_train_loss=0.90549357, val_loss=1.45023313]
# Validation Epoch [19/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.72it/s, val_loss=1.41855663]
# Training Epoch [20/50]: 100%|██████████████████████████████████████████| 4/4 [00:00<00:00,  9.90it/s, curr_train_loss=0.83232415, val_loss=1.41855663]
# Validation Epoch [20/50]: 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,
 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 40.66it/s, val_loss=1.06803514]
# Finished training!

# %% [markdown]
# Let's have a look at the validation accuracy of the two different classifiers and compare them. And don't forget that you can also monitor your training in TensorBoard.
#
# We will only look at the test accuracy and compare our two classifiers with respect to that in the very end.

# %%
val_acc_scratch = classifier.getAcc(labled_val_loader)[1]*100
color = 'green' if val_acc_scratch > 55 else 'red'
print(f"Validation accuracy when training from scratch: {bcolors.colorize(color, val_acc_scratch)}%")

val_acc_pretrained = classifier_pretrained.getAcc(labled_val_loader)[1]*100
color = 'green' if val_acc_pretrained > 55 else 'red'
print(f"Validation accuracy with pretraining: {bcolors.colorize(color, val_acc_pretrained)}%")
# Out:
# Validation accuracy when training from scratch: 66.0%
# Validation accuracy with pretraining: 71.0%

# %% [markdown]
# Now that everything is working, feel free to play around with different architectures. As you've seen, it's quite easy to define your model or do adpations there.
#
# To pass this submission, you will need to achieve an accuracy of **55%**.

# %% [markdown]
# # Save your model & Report Test Accuracy
#
# When you are finally done with your **hyperparameter tuning**, achieved **at least 55% validation accuracy** and are happy with your final model, you can save it here.
#
# Before that, please check again whether the number of parameters is below 5 Mio and the file size is below 20 MB.
#
# Once your final model is saved, we'll finally report the test accuracy.

# %%
from exercise_code.Util import test_and_save
test_dl = torch.utils.data.DataLoader(test_100_dataset, batch_size=4, shuffle=False)

test_acc = classifier.getAcc(test_dl)[1]*100
color = 'green' if test_acc > 55 else 'red'
print(f"Test accuracy when training from scratch: {bcolors.colorize(color, test_acc)}%")

test_acc = classifier_pretrained.getAcc(test_dl)[1]*100
color = 'green' if test_acc > 55 else 'red'
print(f"Test accuracy with pretraining: {bcolors.colorize(color, test_acc)}%")

test_and_save(classifier_pretrained, labled_val_loader, test_dl)
# Out:
# Test accuracy when training from scratch: 62.0%
# Test accuracy with pretraining: 68.0%
# Validation Accuracy: 71.0%
# # Paramters: Your model has 1.159 mio. params.
# Size: Great! Your model size is 18.7 MB and is less than 20 MB.
# Your model has been saved and is ready to be submitted.

# %%
# Now zip the folder for upload
from exercise_code.submit import submit_exercise

submit_exercise('../output/exercise_08')
# Out:
# relevant folders: ['exercise_code', 'models']
# notebooks files: ['1_Autoencoder.ipynb', 'Optional-BatchNormalization_Dropout.ipynb']
# Adding folder exercise_code
# Adding folder models
# Adding notebook 1_Autoencoder.ipynb
# Adding notebook Optional-BatchNormalization_Dropout.ipynb
# Zipping successful! Zip is stored under: /Users/Hoang_1/Desktop/i2dl/output/exercise_08.zip

# %% [markdown]
# Congratulations on completing your first autoencoder and successfully transferring the weights to a classifier! It's remarkable how much easier this process becomes with the power of PyTorch, compared to working with plain NumPy, right?
#
# To complete the exercise, please submit your final model to [our submission portal](https://i2dl.vc.in.tum.de/) - you should be already familiar with the submission procedure. Next, it is time to get started with some more complex neural networks and tasks in the upcoming exercises. See you next week!
#
# # Submission Goals
#
# - Goal: Successfully implement a fully connected autoencoder for MNIST with Pytorch and transfer the encoder weights to a classifier.
#
# - Passing Criteria: There are no unit tests that check specific components of your code. The only thing that's required to pass the submission, is your model to reach at least **55% accuracy** on __our__ test dataset. The submission system will show you a number between 0 and 100 which corresponds to your accuracy.
#
#
# - You can make **$\infty$** submissions until the deadline. Your __best submission__ will be considered for the bonus.
